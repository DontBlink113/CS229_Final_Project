# %%
from read_casia import extract_samples_by_user
from read_casia import extract_chars_dict
from read_casia import merge_dict

chars0_train = extract_chars_dict("Pot1.0Train") #data struct by char
chars0_test = extract_chars_dict("Pot1.0Test") #data struct by char
chars1_train = extract_chars_dict("Pot1.1Train") #data struct by char
chars1_test = extract_chars_dict("Pot1.1Test") #data struct by char
# Out:
# loaded Pot1.0Train/001.pot
# loaded Pot1.0Train/002.pot
# loaded Pot1.0Train/003.pot
# loaded Pot1.0Train/004.pot
# loaded Pot1.0Train/005.pot
# loaded Pot1.0Train/007.pot
# loaded Pot1.0Train/008.pot
# loaded Pot1.0Train/009.pot
# loaded Pot1.0Train/010.pot
# loaded Pot1.0Train/011.pot
# loaded Pot1.0Train/012.pot
# loaded Pot1.0Train/014.pot
# loaded Pot1.0Train/015.pot
# loaded Pot1.0Train/016.pot
# loaded Pot1.0Train/017.pot
# loaded Pot1.0Train/018.pot
# loaded Pot1.0Train/019.pot
# loaded Pot1.0Train/021.pot
# loaded Pot1.0Train/022.pot
# loaded Pot1.0Train/023.pot
# loaded Pot1.0Train/024.pot
# loaded Pot1.0Train/025.pot
# loaded Pot1.0Train/026.pot
# loaded Pot1.0Train/027.pot
# loaded Pot1.0Train/028.pot
# loaded Pot1.0Train/030.pot
# loaded Pot1.0Train/031.pot
# loaded Pot1.0Train/032.pot
# loaded Pot1.0Train/033.pot
# loaded Pot1.0Train/034.pot
# loaded Pot1.0Train/035.pot
# loaded Pot1.0Train/036.pot
# loaded Pot1.0Train/037.pot
# loaded Pot1.0Train/039.pot
# loaded Pot1.0Train/040.pot
# loaded Pot1.0Train/041.pot
# loaded Pot1.0Train/043.pot
# loaded Pot1.0Train/044.pot
# loaded Pot1.0Train/045.pot
# loaded Pot1.0Train/047.pot
# loaded Pot1.0Train/048.pot
# loaded Pot1.0Train/049.pot
# loaded Pot1.0Train/050.pot
# loaded Pot1.0Train/051.pot
# loaded Pot1.0Train/052.pot
# loaded Pot1.0Train/053.pot
# loaded Pot1.0Train/054.pot
# loaded Pot1.0Train/055.pot
# loaded Pot1.0Train/056.pot
# loaded Pot1.0Train/057.pot
# loaded Pot1.0Train/059.pot
# loaded Pot1.0Train/061.pot
# loaded Pot1.0Train/063.pot
# loaded Pot1.0Train/064.pot
# loaded Pot1.0Train/065.pot
# loaded Pot1.0Train/066.pot
# loaded Pot1.0Train/067.pot
# loaded Pot1.0Train/068.pot
# loaded Pot1.0Train/070.pot
# loaded Pot1.0Train/071.pot
# loaded Pot1.0Train/072.pot
# loaded Pot1.0Train/074.pot
# loaded Pot1.0Train/075.pot
# loaded Pot1.0Train/076.pot
# loaded Pot1.0Train/077.pot
# loaded Pot1.0Train/078.pot
# loaded Pot1.0Train/079.pot
# loaded Pot1.0Train/080.pot
# loaded Pot1.0Train/081.pot
# loaded Pot1.0Train/083.pot
# loaded Pot1.0Train/085.pot
# loaded Pot1.0Train/086.pot
# loaded Pot1.0Train/087.pot
# loaded Pot1.0Train/088.pot
# loaded Pot1.0Train/089.pot
# loaded Pot1.0Train/090.pot
# loaded Pot1.0Train/091.pot
# loaded Pot1.0Train/092.pot
# loaded Pot1.0Train/093.pot
# loaded Pot1.0Train/094.pot
# loaded Pot1.0Train/095.pot
# loaded Pot1.0Train/096.pot
# loaded Pot1.0Train/098.pot
# loaded Pot1.0Train/099.pot
# loaded Pot1.0Train/100.pot
# loaded Pot1.0Train/101.pot
# loaded Pot1.0Train/102.pot
# loaded Pot1.0Train/103.pot
# loaded Pot1.0Train/105.pot
# loaded Pot1.0Train/106.pot
# loaded Pot1.0Train/107.pot
# loaded Pot1.0Train/109.pot
# loaded Pot1.0Train/110.pot
# loaded Pot1.0Train/112.pot
# loaded Pot1.0Train/114.pot
# loaded Pot1.0Train/115.pot
# loaded Pot1.0Train/116.pot
# loaded Pot1.0Train/117.pot
# loaded Pot1.0Train/118.pot
# loaded Pot1.0Train/119.pot
# loaded Pot1.0Train/120.pot
# loaded Pot1.0Train/122.pot
# loaded Pot1.0Train/123.pot
# loaded Pot1.0Train/126.pot
# loaded Pot1.0Train/127.pot
# loaded Pot1.0Train/128.pot
# loaded Pot1.0Train/129.pot
# loaded Pot1.0Train/130.pot
# loaded Pot1.0Train/131.pot
# loaded Pot1.0Train/133.pot
# loaded Pot1.0Train/134.pot
# loaded Pot1.0Train/135.pot
# loaded Pot1.0Train/137.pot
# loaded Pot1.0Train/138.pot
# loaded Pot1.0Train/139.pot
# loaded Pot1.0Train/140.pot
# loaded Pot1.0Train/141.pot
# loaded Pot1.0Train/142.pot
# loaded Pot1.0Train/143.pot
# loaded Pot1.0Train/144.pot
# loaded Pot1.0Train/145.pot
# loaded Pot1.0Train/146.pot
# loaded Pot1.0Train/148.pot
# loaded Pot1.0Train/149.pot
# loaded Pot1.0Train/151.pot
# loaded Pot1.0Train/152.pot
# loaded Pot1.0Train/154.pot
# loaded Pot1.0Train/155.pot
# loaded Pot1.0Train/159.pot
# loaded Pot1.0Train/161.pot
# loaded Pot1.0Train/162.pot
# loaded Pot1.0Train/163.pot
# loaded Pot1.0Train/164.pot
# loaded Pot1.0Train/165.pot
# loaded Pot1.0Train/166.pot
# loaded Pot1.0Train/167.pot
# loaded Pot1.0Train/170.pot
# loaded Pot1.0Train/171.pot
# loaded Pot1.0Train/174.pot
# loaded Pot1.0Train/175.pot
# loaded Pot1.0Train/176.pot
# loaded Pot1.0Train/177.pot
# loaded Pot1.0Train/178.pot
# loaded Pot1.0Train/179.pot
# loaded Pot1.0Train/180.pot
# loaded Pot1.0Train/182.pot
# loaded Pot1.0Train/183.pot
# loaded Pot1.0Train/184.pot
# loaded Pot1.0Train/185.pot
# loaded Pot1.0Train/186.pot
# loaded Pot1.0Train/188.pot
# loaded Pot1.0Train/190.pot
# loaded Pot1.0Train/191.pot
# loaded Pot1.0Train/192.pot
# loaded Pot1.0Train/196.pot
# loaded Pot1.0Train/197.pot
# loaded Pot1.0Train/198.pot
# loaded Pot1.0Train/199.pot
# loaded Pot1.0Train/200.pot
# loaded Pot1.0Train/201.pot
# loaded Pot1.0Train/203.pot
# loaded Pot1.0Train/204.pot
# loaded Pot1.0Train/206.pot
# loaded Pot1.0Train/207.pot
# loaded Pot1.0Train/208.pot
# loaded Pot1.0Train/209.pot
# loaded Pot1.0Train/210.pot
# loaded Pot1.0Train/211.pot
# loaded Pot1.0Train/212.pot
# loaded Pot1.0Train/214.pot
# loaded Pot1.0Train/215.pot
# loaded Pot1.0Train/216.pot
# loaded Pot1.0Train/217.pot
# loaded Pot1.0Train/218.pot
# loaded Pot1.0Train/220.pot
# loaded Pot1.0Train/221.pot
# loaded Pot1.0Train/222.pot
# loaded Pot1.0Train/223.pot
# loaded Pot1.0Train/224.pot
# loaded Pot1.0Train/225.pot
# loaded Pot1.0Train/227.pot
# loaded Pot1.0Train/228.pot
# loaded Pot1.0Train/230.pot
# loaded Pot1.0Train/231.pot
# loaded Pot1.0Train/232.pot
# loaded Pot1.0Train/233.pot
# loaded Pot1.0Train/234.pot
# loaded Pot1.0Train/236.pot
# loaded Pot1.0Train/237.pot
# loaded Pot1.0Train/238.pot
# loaded Pot1.0Train/239.pot
# loaded Pot1.0Train/243.pot
# loaded Pot1.0Train/244.pot
# loaded Pot1.0Train/245.pot
# loaded Pot1.0Train/247.pot
# loaded Pot1.0Train/249.pot
# loaded Pot1.0Train/251.pot
# loaded Pot1.0Train/252.pot
# loaded Pot1.0Train/255.pot
# loaded Pot1.0Train/257.pot
# loaded Pot1.0Train/258.pot
# loaded Pot1.0Train/259.pot
# loaded Pot1.0Train/260.pot
# loaded Pot1.0Train/261.pot
# loaded Pot1.0Train/262.pot
# loaded Pot1.0Train/263.pot
# loaded Pot1.0Train/264.pot
# loaded Pot1.0Train/266.pot
# loaded Pot1.0Train/267.pot
# loaded Pot1.0Train/269.pot
# loaded Pot1.0Train/270.pot
# loaded Pot1.0Train/271.pot
# loaded Pot1.0Train/272.pot
# loaded Pot1.0Train/273.pot
# loaded Pot1.0Train/274.pot
# loaded Pot1.0Train/275.pot
# loaded Pot1.0Train/277.pot
# loaded Pot1.0Train/279.pot
# loaded Pot1.0Train/280.pot
# loaded Pot1.0Train/281.pot
# loaded Pot1.0Train/283.pot
# loaded Pot1.0Train/284.pot
# loaded Pot1.0Train/285.pot
# loaded Pot1.0Train/286.pot
# loaded Pot1.0Train/287.pot
# loaded Pot1.0Train/288.pot
# loaded Pot1.0Train/289.pot
# loaded Pot1.0Train/290.pot
# loaded Pot1.0Train/291.pot
# loaded Pot1.0Train/292.pot
# loaded Pot1.0Train/294.pot
# loaded Pot1.0Train/295.pot
# loaded Pot1.0Train/296.pot
# loaded Pot1.0Train/298.pot
# loaded Pot1.0Train/299.pot
# loaded Pot1.0Train/301.pot
# loaded Pot1.0Train/303.pot
# loaded Pot1.0Train/304.pot
# loaded Pot1.0Train/305.pot
# loaded Pot1.0Train/306.pot
# loaded Pot1.0Train/307.pot
# loaded Pot1.0Train/308.pot
# loaded Pot1.0Train/309.pot
# loaded Pot1.0Train/310.pot
# loaded Pot1.0Train/311.pot
# loaded Pot1.0Train/312.pot
# loaded Pot1.0Train/313.pot
# loaded Pot1.0Train/314.pot
# loaded Pot1.0Train/315.pot
# loaded Pot1.0Train/316.pot
# loaded Pot1.0Train/318.pot
# loaded Pot1.0Train/319.pot
# loaded Pot1.0Train/320.pot
# loaded Pot1.0Train/321.pot
# loaded Pot1.0Train/322.pot
# loaded Pot1.0Train/323.pot
# loaded Pot1.0Train/324.pot
# loaded Pot1.0Train/325.pot
# loaded Pot1.0Train/327.pot
# loaded Pot1.0Train/328.pot
# loaded Pot1.0Train/329.pot
# loaded Pot1.0Train/330.pot
# loaded Pot1.0Train/331.pot
# loaded Pot1.0Train/332.pot
# loaded Pot1.0Train/333.pot
# loaded Pot1.0Train/334.pot
# loaded Pot1.0Train/335.pot
# loaded Pot1.0Train/336.pot
# loaded Pot1.0Train/337.pot
# loaded Pot1.0Train/338.pot
# loaded Pot1.0Train/339.pot
# loaded Pot1.0Train/340.pot
# loaded Pot1.0Train/342.pot
# loaded Pot1.0Train/343.pot
# loaded Pot1.0Train/344.pot
# loaded Pot1.0Train/346.pot
# loaded Pot1.0Train/347.pot
# loaded Pot1.0Train/348.pot
# loaded Pot1.0Train/349.pot
# loaded Pot1.0Train/350.pot
# loaded Pot1.0Train/352.pot
# loaded Pot1.0Train/353.pot
# loaded Pot1.0Train/354.pot
# loaded Pot1.0Train/355.pot
# loaded Pot1.0Train/356.pot
# loaded Pot1.0Train/357.pot
# loaded Pot1.0Train/358.pot
# loaded Pot1.0Train/359.pot
# loaded Pot1.0Train/360.pot
# loaded Pot1.0Train/362.pot
# loaded Pot1.0Train/363.pot
# loaded Pot1.0Train/364.pot
# loaded Pot1.0Train/365.pot
# loaded Pot1.0Train/366.pot
# loaded Pot1.0Train/367.pot
# loaded Pot1.0Train/368.pot
# loaded Pot1.0Train/369.pot
# loaded Pot1.0Train/370.pot
# loaded Pot1.0Train/372.pot
# loaded Pot1.0Train/373.pot
# loaded Pot1.0Train/374.pot
# loaded Pot1.0Train/375.pot
# loaded Pot1.0Train/378.pot
# loaded Pot1.0Train/379.pot
# loaded Pot1.0Train/380.pot
# loaded Pot1.0Train/381.pot
# loaded Pot1.0Train/383.pot
# loaded Pot1.0Train/384.pot
# loaded Pot1.0Train/385.pot
# loaded Pot1.0Train/387.pot
# loaded Pot1.0Train/388.pot
# loaded Pot1.0Train/389.pot
# loaded Pot1.0Train/390.pot
# loaded Pot1.0Train/392.pot
# loaded Pot1.0Train/393.pot
# loaded Pot1.0Train/395.pot
# loaded Pot1.0Train/397.pot
# loaded Pot1.0Train/399.pot
# loaded Pot1.0Train/401.pot
# loaded Pot1.0Train/402.pot
# loaded Pot1.0Train/403.pot
# loaded Pot1.0Train/404.pot
# loaded Pot1.0Train/405.pot
# loaded Pot1.0Train/406.pot
# loaded Pot1.0Train/407.pot
# loaded Pot1.0Train/408.pot
# loaded Pot1.0Train/409.pot
# loaded Pot1.0Train/411.pot
# loaded Pot1.0Train/412.pot
# loaded Pot1.0Train/413.pot
# loaded Pot1.0Train/414.pot
# loaded Pot1.0Train/415.pot
# loaded Pot1.0Train/416.pot
# loaded Pot1.0Train/417.pot
# loaded Pot1.0Train/418.pot
# loaded Pot1.0Train/420.pot
# loaded Pot1.0Test/006.pot
# loaded Pot1.0Test/013.pot
# loaded Pot1.0Test/020.pot
# loaded Pot1.0Test/029.pot
# loaded Pot1.0Test/038.pot
# loaded Pot1.0Test/042.pot
# loaded Pot1.0Test/046.pot
# loaded Pot1.0Test/058.pot
# loaded Pot1.0Test/060.pot
# loaded Pot1.0Test/062.pot
# loaded Pot1.0Test/069.pot
# loaded Pot1.0Test/073.pot
# loaded Pot1.0Test/082.pot
# loaded Pot1.0Test/084.pot
# loaded Pot1.0Test/097.pot
# loaded Pot1.0Test/104.pot
# loaded Pot1.0Test/108.pot
# loaded Pot1.0Test/111.pot
# loaded Pot1.0Test/113.pot
# loaded Pot1.0Test/121.pot
# loaded Pot1.0Test/124.pot
# loaded Pot1.0Test/125.pot
# loaded Pot1.0Test/132.pot
# loaded Pot1.0Test/136.pot
# loaded Pot1.0Test/147.pot
# loaded Pot1.0Test/150.pot
# loaded Pot1.0Test/153.pot
# loaded Pot1.0Test/156.pot
# loaded Pot1.0Test/157.pot
# loaded Pot1.0Test/158.pot
# loaded Pot1.0Test/160.pot
# loaded Pot1.0Test/168.pot
# loaded Pot1.0Test/169.pot
# loaded Pot1.0Test/172.pot
# loaded Pot1.0Test/173.pot
# loaded Pot1.0Test/181.pot
# loaded Pot1.0Test/187.pot
# loaded Pot1.0Test/189.pot
# loaded Pot1.0Test/193.pot
# loaded Pot1.0Test/194.pot
# loaded Pot1.0Test/195.pot
# loaded Pot1.0Test/202.pot
# loaded Pot1.0Test/205.pot
# loaded Pot1.0Test/213.pot
# loaded Pot1.0Test/219.pot
# loaded Pot1.0Test/226.pot
# loaded Pot1.0Test/229.pot
# loaded Pot1.0Test/235.pot
# loaded Pot1.0Test/240.pot
# loaded Pot1.0Test/241.pot
# loaded Pot1.0Test/242.pot
# loaded Pot1.0Test/246.pot
# loaded Pot1.0Test/248.pot
# loaded Pot1.0Test/250.pot
# loaded Pot1.0Test/253.pot
# loaded Pot1.0Test/254.pot
# loaded Pot1.0Test/256.pot
# loaded Pot1.0Test/265.pot
# loaded Pot1.0Test/268.pot
# loaded Pot1.0Test/276.pot
# loaded Pot1.0Test/278.pot
# loaded Pot1.0Test/282.pot
# loaded Pot1.0Test/293.pot
# loaded Pot1.0Test/297.pot
# loaded Pot1.0Test/300.pot
# loaded Pot1.0Test/302.pot
# loaded Pot1.0Test/317.pot
# loaded Pot1.0Test/326.pot
# loaded Pot1.0Test/341.pot
# loaded Pot1.0Test/345.pot
# loaded Pot1.0Test/351.pot
# loaded Pot1.0Test/361.pot
# loaded Pot1.0Test/371.pot
# loaded Pot1.0Test/376.pot
# loaded Pot1.0Test/377.pot
# loaded Pot1.0Test/382.pot
# loaded Pot1.0Test/386.pot
# loaded Pot1.0Test/391.pot
# loaded Pot1.0Test/394.pot
# loaded Pot1.0Test/396.pot
# loaded Pot1.0Test/398.pot
# loaded Pot1.0Test/400.pot
# loaded Pot1.0Test/410.pot
# loaded Pot1.0Test/419.pot
# loaded Pot1.1Train/1001.pot
# loaded Pot1.1Train/1002.pot
# loaded Pot1.1Train/1003.pot
# loaded Pot1.1Train/1004.pot
# loaded Pot1.1Train/1005.pot
# loaded Pot1.1Train/1006.pot
# loaded Pot1.1Train/1007.pot
# loaded Pot1.1Train/1008.pot
# loaded Pot1.1Train/1009.pot
# loaded Pot1.1Train/1010.pot
# loaded Pot1.1Train/1011.pot
# loaded Pot1.1Train/1012.pot
# loaded Pot1.1Train/1013.pot
# loaded Pot1.1Train/1014.pot
# loaded Pot1.1Train/1015.pot
# loaded Pot1.1Train/1016.pot
# loaded Pot1.1Train/1017.pot
# loaded Pot1.1Train/1018.pot
# loaded Pot1.1Train/1019.pot
# loaded Pot1.1Train/1020.pot
# loaded Pot1.1Train/1021.pot
# loaded Pot1.1Train/1022.pot
# loaded Pot1.1Train/1023.pot
# loaded Pot1.1Train/1024.pot
# loaded Pot1.1Train/1025.pot
# loaded Pot1.1Train/1026.pot
# loaded Pot1.1Train/1027.pot
# loaded Pot1.1Train/1028.pot
# loaded Pot1.1Train/1029.pot
# loaded Pot1.1Train/1030.pot
# loaded Pot1.1Train/1031.pot
# loaded Pot1.1Train/1032.pot
# loaded Pot1.1Train/1033.pot
# loaded Pot1.1Train/1034.pot
# loaded Pot1.1Train/1035.pot
# loaded Pot1.1Train/1036.pot
# loaded Pot1.1Train/1037.pot
# loaded Pot1.1Train/1038.pot
# loaded Pot1.1Train/1039.pot
# loaded Pot1.1Train/1040.pot
# loaded Pot1.1Train/1041.pot
# loaded Pot1.1Train/1042.pot
# loaded Pot1.1Train/1043.pot
# loaded Pot1.1Train/1044.pot
# loaded Pot1.1Train/1045.pot
# loaded Pot1.1Train/1046.pot
# loaded Pot1.1Train/1047.pot
# loaded Pot1.1Train/1048.pot
# loaded Pot1.1Train/1049.pot
# loaded Pot1.1Train/1050.pot
# loaded Pot1.1Train/1051.pot
# loaded Pot1.1Train/1052.pot
# loaded Pot1.1Train/1053.pot
# loaded Pot1.1Train/1054.pot
# loaded Pot1.1Train/1055.pot
# loaded Pot1.1Train/1056.pot
# loaded Pot1.1Train/1057.pot
# loaded Pot1.1Train/1058.pot
# loaded Pot1.1Train/1059.pot
# loaded Pot1.1Train/1060.pot
# loaded Pot1.1Train/1061.pot
# loaded Pot1.1Train/1062.pot
# loaded Pot1.1Train/1063.pot
# loaded Pot1.1Train/1064.pot
# loaded Pot1.1Train/1065.pot
# loaded Pot1.1Train/1066.pot
# loaded Pot1.1Train/1067.pot
# loaded Pot1.1Train/1068.pot
# loaded Pot1.1Train/1069.pot
# loaded Pot1.1Train/1070.pot
# loaded Pot1.1Train/1071.pot
# loaded Pot1.1Train/1072.pot
# loaded Pot1.1Train/1073.pot
# loaded Pot1.1Train/1074.pot
# loaded Pot1.1Train/1075.pot
# loaded Pot1.1Train/1076.pot
# loaded Pot1.1Train/1077.pot
# loaded Pot1.1Train/1078.pot
# loaded Pot1.1Train/1079.pot
# loaded Pot1.1Train/1080.pot
# loaded Pot1.1Train/1081.pot
# loaded Pot1.1Train/1082.pot
# loaded Pot1.1Train/1083.pot
# loaded Pot1.1Train/1084.pot
# loaded Pot1.1Train/1085.pot
# loaded Pot1.1Train/1086.pot
# loaded Pot1.1Train/1087.pot
# loaded Pot1.1Train/1088.pot
# loaded Pot1.1Train/1089.pot
# loaded Pot1.1Train/1090.pot
# loaded Pot1.1Train/1091.pot
# loaded Pot1.1Train/1092.pot
# loaded Pot1.1Train/1093.pot
# loaded Pot1.1Train/1094.pot
# loaded Pot1.1Train/1095.pot
# loaded Pot1.1Train/1096.pot
# loaded Pot1.1Train/1097.pot
# loaded Pot1.1Train/1098.pot
# loaded Pot1.1Train/1099.pot
# loaded Pot1.1Train/1100.pot
# loaded Pot1.1Train/1101.pot
# loaded Pot1.1Train/1102.pot
# loaded Pot1.1Train/1103.pot
# loaded Pot1.1Train/1104.pot
# loaded Pot1.1Train/1105.pot
# loaded Pot1.1Train/1106.pot
# loaded Pot1.1Train/1107.pot
# loaded Pot1.1Train/1108.pot
# loaded Pot1.1Train/1109.pot
# loaded Pot1.1Train/1110.pot
# loaded Pot1.1Train/1111.pot
# loaded Pot1.1Train/1112.pot
# loaded Pot1.1Train/1113.pot
# loaded Pot1.1Train/1114.pot
# loaded Pot1.1Train/1115.pot
# loaded Pot1.1Train/1116.pot
# loaded Pot1.1Train/1117.pot
# loaded Pot1.1Train/1118.pot
# loaded Pot1.1Train/1119.pot
# loaded Pot1.1Train/1120.pot
# loaded Pot1.1Train/1121.pot
# loaded Pot1.1Train/1122.pot
# loaded Pot1.1Train/1123.pot
# loaded Pot1.1Train/1124.pot
# loaded Pot1.1Train/1125.pot
# loaded Pot1.1Train/1126.pot
# loaded Pot1.1Train/1127.pot
# loaded Pot1.1Train/1128.pot
# loaded Pot1.1Train/1129.pot
# loaded Pot1.1Train/1130.pot
# loaded Pot1.1Train/1131.pot
# loaded Pot1.1Train/1132.pot
# loaded Pot1.1Train/1133.pot
# loaded Pot1.1Train/1134.pot
# loaded Pot1.1Train/1135.pot
# loaded Pot1.1Train/1136.pot
# loaded Pot1.1Train/1137.pot
# loaded Pot1.1Train/1138.pot
# loaded Pot1.1Train/1139.pot
# loaded Pot1.1Train/1140.pot
# loaded Pot1.1Train/1141.pot
# loaded Pot1.1Train/1142.pot
# loaded Pot1.1Train/1143.pot
# loaded Pot1.1Train/1144.pot
# loaded Pot1.1Train/1145.pot
# loaded Pot1.1Train/1146.pot
# loaded Pot1.1Train/1147.pot
# loaded Pot1.1Train/1148.pot
# loaded Pot1.1Train/1149.pot
# loaded Pot1.1Train/1150.pot
# loaded Pot1.1Train/1151.pot
# loaded Pot1.1Train/1152.pot
# loaded Pot1.1Train/1153.pot
# loaded Pot1.1Train/1154.pot
# loaded Pot1.1Train/1155.pot
# loaded Pot1.1Train/1156.pot
# loaded Pot1.1Train/1157.pot
# loaded Pot1.1Train/1158.pot
# loaded Pot1.1Train/1159.pot
# loaded Pot1.1Train/1160.pot
# loaded Pot1.1Train/1161.pot
# loaded Pot1.1Train/1162.pot
# loaded Pot1.1Train/1163.pot
# loaded Pot1.1Train/1164.pot
# loaded Pot1.1Train/1165.pot
# loaded Pot1.1Train/1166.pot
# loaded Pot1.1Train/1167.pot
# loaded Pot1.1Train/1168.pot
# loaded Pot1.1Train/1169.pot
# loaded Pot1.1Train/1170.pot
# loaded Pot1.1Train/1171.pot
# loaded Pot1.1Train/1172.pot
# loaded Pot1.1Train/1173.pot
# loaded Pot1.1Train/1174.pot
# loaded Pot1.1Train/1175.pot
# loaded Pot1.1Train/1176.pot
# loaded Pot1.1Train/1177.pot
# loaded Pot1.1Train/1178.pot
# loaded Pot1.1Train/1179.pot
# loaded Pot1.1Train/1180.pot
# loaded Pot1.1Train/1181.pot
# loaded Pot1.1Train/1182.pot
# loaded Pot1.1Train/1183.pot
# loaded Pot1.1Train/1184.pot
# loaded Pot1.1Train/1185.pot
# loaded Pot1.1Train/1186.pot
# loaded Pot1.1Train/1187.pot
# loaded Pot1.1Train/1188.pot
# loaded Pot1.1Train/1189.pot
# loaded Pot1.1Train/1190.pot
# loaded Pot1.1Train/1191.pot
# loaded Pot1.1Train/1192.pot
# loaded Pot1.1Train/1193.pot
# loaded Pot1.1Train/1194.pot
# loaded Pot1.1Train/1195.pot
# loaded Pot1.1Train/1196.pot
# loaded Pot1.1Train/1197.pot
# loaded Pot1.1Train/1198.pot
# loaded Pot1.1Train/1199.pot
# loaded Pot1.1Train/1200.pot
# loaded Pot1.1Train/1201.pot
# loaded Pot1.1Train/1202.pot
# loaded Pot1.1Train/1203.pot
# loaded Pot1.1Train/1204.pot
# loaded Pot1.1Train/1205.pot
# loaded Pot1.1Train/1206.pot
# loaded Pot1.1Train/1207.pot
# loaded Pot1.1Train/1208.pot
# loaded Pot1.1Train/1209.pot
# loaded Pot1.1Train/1210.pot
# loaded Pot1.1Train/1211.pot
# loaded Pot1.1Train/1212.pot
# loaded Pot1.1Train/1213.pot
# loaded Pot1.1Train/1214.pot
# loaded Pot1.1Train/1215.pot
# loaded Pot1.1Train/1216.pot
# loaded Pot1.1Train/1217.pot
# loaded Pot1.1Train/1218.pot
# loaded Pot1.1Train/1219.pot
# loaded Pot1.1Train/1220.pot
# loaded Pot1.1Train/1221.pot
# loaded Pot1.1Train/1222.pot
# loaded Pot1.1Train/1223.pot
# loaded Pot1.1Train/1224.pot
# loaded Pot1.1Train/1225.pot
# loaded Pot1.1Train/1226.pot
# loaded Pot1.1Train/1227.pot
# loaded Pot1.1Train/1228.pot
# loaded Pot1.1Train/1229.pot
# loaded Pot1.1Train/1230.pot
# loaded Pot1.1Train/1231.pot
# loaded Pot1.1Train/1232.pot
# loaded Pot1.1Train/1233.pot
# loaded Pot1.1Train/1234.pot
# loaded Pot1.1Train/1235.pot
# loaded Pot1.1Train/1236.pot
# loaded Pot1.1Train/1237.pot
# loaded Pot1.1Train/1238.pot
# loaded Pot1.1Train/1239.pot
# loaded Pot1.1Train/1240.pot
# loaded Pot1.1Test/1241.pot
# loaded Pot1.1Test/1242.pot
# loaded Pot1.1Test/1243.pot
# loaded Pot1.1Test/1244.pot
# loaded Pot1.1Test/1245.pot
# loaded Pot1.1Test/1246.pot
# loaded Pot1.1Test/1247.pot
# loaded Pot1.1Test/1248.pot
# loaded Pot1.1Test/1249.pot
# loaded Pot1.1Test/1250.pot
# loaded Pot1.1Test/1251.pot
# loaded Pot1.1Test/1252.pot
# loaded Pot1.1Test/1253.pot
# loaded Pot1.1Test/1254.pot
# loaded Pot1.1Test/1255.pot
# loaded Pot1.1Test/1256.pot
# loaded Pot1.1Test/1257.pot
# loaded Pot1.1Test/1258.pot
# loaded Pot1.1Test/1259.pot
# loaded Pot1.1Test/1260.pot
# loaded Pot1.1Test/1261.pot
# loaded Pot1.1Test/1262.pot
# loaded Pot1.1Test/1263.pot
# loaded Pot1.1Test/1264.pot
# loaded Pot1.1Test/1265.pot
# loaded Pot1.1Test/1266.pot
# loaded Pot1.1Test/1267.pot
# loaded Pot1.1Test/1268.pot
# loaded Pot1.1Test/1269.pot
# loaded Pot1.1Test/1270.pot
# loaded Pot1.1Test/1271.pot
# loaded Pot1.1Test/1272.pot
# loaded Pot1.1Test/1273.pot
# loaded Pot1.1Test/1274.pot
# loaded Pot1.1Test/1275.pot
# loaded Pot1.1Test/1276.pot
# loaded Pot1.1Test/1277.pot
# loaded Pot1.1Test/1278.pot
# loaded Pot1.1Test/1279.pot
# loaded Pot1.1Test/1280.pot
# loaded Pot1.1Test/1281.pot
# loaded Pot1.1Test/1282.pot
# loaded Pot1.1Test/1283.pot
# loaded Pot1.1Test/1284.pot
# loaded Pot1.1Test/1285.pot
# loaded Pot1.1Test/1286.pot
# loaded Pot1.1Test/1287.pot
# loaded Pot1.1Test/1288.pot
# loaded Pot1.1Test/1289.pot
# loaded Pot1.1Test/1290.pot
# loaded Pot1.1Test/1291.pot
# loaded Pot1.1Test/1292.pot
# loaded Pot1.1Test/1293.pot
# loaded Pot1.1Test/1294.pot
# loaded Pot1.1Test/1295.pot
# loaded Pot1.1Test/1296.pot
# loaded Pot1.1Test/1297.pot
# loaded Pot1.1Test/1298.pot
# loaded Pot1.1Test/1299.pot
# loaded Pot1.1Test/1300.pot

# %%
from read_casia import display_pot_samples
train = merge_dict(chars0_train, chars1_train)
test = merge_dict(chars0_test, chars1_test)

print(chars0_train['喝'][0])
print(chars0_train['喝'][0])
display_pot_samples(chars0_train['喝'])
# Out:
# [[(2849, 8405), (2850, 8405), (2854, 8445), (2854, 8459), (2855, 8469), (2855, 8474), (2855, 8475), (2855, 8475), (2851, 8472), (2848, 8459)], [(2855, 8420), (2855, 8420), (2856, 8420), (2876, 8419), (2885, 8424), (2881, 8457), (2870, 8475), (2864, 8480), (2860, 8480), (2859, 8480), (2883, 8469), (2896, 8459), (2900, 8449), (2894, 8434)], [(2933, 8367), (2933, 8367), (2936, 8400), (2935, 8412), (2934, 8420), (2933, 8424), (2933, 8425), (2931, 8425), (2929, 8420), (2925, 8409)], [(2933, 8374), (2934, 8370), (2950, 8362), (2979, 8359), (2971, 8424), (2961, 8420), (2950, 8415)], [(2938, 8405), (2938, 8404), (2954, 8399), (2968, 8395), (2933, 8435), (2963, 8425), (2921, 8475), (2990, 8447), (3001, 8450), (3008, 8460), (3000, 8485), (2978, 8519), (2968, 8520), (2963, 8505), (2971, 8460), (2974, 8457), (2961, 8480), (2946, 8497), (2955, 8489), (2979, 8484), (2973, 8484), (2965, 8485), (2955, 8484)], [(2943, 8482), (2939, 8487), (2933, 8504), (2934, 8512), (2946, 8512), (2966, 8505), (2988, 8495), (2984, 8482)]]
# [[(2849, 8405), (2850, 8405), (2854, 8445), (2854, 8459), (2855, 8469), (2855, 8474), (2855, 8475), (2855, 8475), (2851, 8472), (2848, 8459)], [(2855, 8420), (2855, 8420), (2856, 8420), (2876, 8419), (2885, 8424), (2881, 8457), (2870, 8475), (2864, 8480), (2860, 8480), (2859, 8480), (2883, 8469), (2896, 8459), (2900, 8449), (2894, 8434)], [(2933, 8367), (2933, 8367), (2936, 8400), (2935, 8412), (2934, 8420), (2933, 8424), (2933, 8425), (2931, 8425), (2929, 8420), (2925, 8409)], [(2933, 8374), (2934, 8370), (2950, 8362), (2979, 8359), (2971, 8424), (2961, 8420), (2950, 8415)], [(2938, 8405), (2938, 8404), (2954, 8399), (2968, 8395), (2933, 8435), (2963, 8425), (2921, 8475), (2990, 8447), (3001, 8450), (3008, 8460), (3000, 8485), (2978, 8519), (2968, 8520), (2963, 8505), (2971, 8460), (2974, 8457), (2961, 8480), (2946, 8497), (2955, 8489), (2979, 8484), (2973, 8484), (2965, 8485), (2955, 8484)], [(2943, 8482), (2939, 8487), (2933, 8504), (2934, 8512), (2946, 8512), (2966, 8505), (2988, 8495), (2984, 8482)]]

# %%
import importlib
import read_casia  # import the module itself (not just the function)
import feature_extraction

importlib.reload(read_casia)
importlib.reload(feature_extraction)


from read_casia import display_pot_samples  # re-import after reloading
from feature_extraction import plot_feature_vector

# %%
chars = [
"的","一","是","不","了","在","人","有","我","他","这","个","们","中","来","上","大","为","和","国",
"地","到","以","说","时","要","就","出","会","可","也","你","对","生","能","而","子","那","得","于",
"着","下","自","之","年","过","发","后","作","里","用","道","行","所","然","家","种","事","成","方",
"多","经","么","去","法","学","如","都","同","现","当","没","动","面","起","看","定","天","分","还",
"进","好","小","部","其","些","主","样","理","心","她","本","前","开","但","因","只","从","想","实",
"日","军","者","意","无","力","它","与","长","把","机","十","民","第","公","此","已","工","使","情",
"明","性","知","全","三","又","关","点","正","业","外","将","两","高","间","由","问","很","最","重",
"并","物","手","应","战","向","头","文","体","政","美","相","见","被","利","什","二","等","产","或",
"新","己","制","身","果","加","西","斯","月","话","合","回","特","代","内","信","表","化","老","给",
"世","位","次","度","门","任","常","先","海","通","教","儿","原","东","声","提","立","及","比","员",
"解","水","名","真","论","处","走","义","各","入","几","口","认","条","平","系","气","题","活","尔",
"更","别","打","女","变","四","神","总","何","电","数","安","少","报","才","结","反","受","目","太",
"量","再","感","建","务","做","接","必","场","件","计","管","期","市","直","德","资","命","山","金",
"指","克","许","统","区","保","至","队","形","社","便","空","决","治","展","马","科","司","五","基",
"眼","书","非","则","听","白","却","界","达","光","放","强","即","像","难","且","权","思","王","象",
"完","设","式","色","路","记","南","品","住","告","类","求","据","程","北","边","死","张","该","交",
"规","万","取","拉","格","望","觉","术","领","共","确","传","师","观","清","今","切","院","让","识",
"候","带","导","争","运","笑","飞","风","步","改","收","根","干","造","言","联","持","组","每","济",
"车","亲","极","林","服","快","办","议","往","元","英","士","证","近","失","转","夫","令","准","布",
"始","怎","呢","存","未","远","叫","台","单","影","具","罗","字","爱","击","流","备","兵","连","调",
"深","商","算","质","团","集","百","需","价","花","党","华","城","石","级","整","府","离","况","亚",
"请","技","际","约","示","复","病","息","究","线","似","官","火","断","精","满","支","视","消","越",
"器","容","照","须","九","增","研","写","称","企","八","功","吗","包","片","史","委","乎","查","轻",
"易","早","曾","除","农","找","装","广","显","吧","阿","李","标","谈","吃","图","念","六","引","历",
"首","医","局","突","专","费","号","尽","另","周","较","注","语","仅","考","落","青","随","选","列"
]
print(len(chars))
chars_set = set(chars)

train = {k: v for k, v in train.items() if k in chars_set}
test  = {k: v for k, v in test.items()  if k in chars_set}
# Out:
# 500

# %%
from feature_extraction import extract_online_features
from feature_extraction import plot_feature_vector


feat = extract_online_features(chars0_train['喝'][0], normalization='P2DBMN')
plot_feature_vector(feat)

# %%
from feature_extraction import extract_features_batch


#extract the flow field for all chars in the set 
x, y = extract_features_batch(train, normalization='P2DBMN')
# Out:
# label 而 complete
# label 儿 complete
# label 尔 complete
# label 二 complete
# label 发 complete
# label 法 complete
# label 反 complete
# label 方 complete
# label 放 complete
# label 非 complete
# label 飞 complete
# label 费 complete
# label 分 complete
# label 风 complete
# label 夫 complete
# label 服 complete
# label 府 complete
# label 复 complete
# label 该 complete
# label 改 complete
# label 干 complete
# label 感 complete
# label 高 complete
# label 告 complete
# label 格 complete
# label 个 complete
# label 各 complete
# label 给 complete
# label 根 complete
# label 更 complete
# label 工 complete
# label 功 complete
# label 公 complete
# label 共 complete
# label 关 complete
# label 官 complete
# label 观 complete
# label 管 complete
# label 光 complete
# label 广 complete
# label 规 complete
# label 国 complete
# label 果 complete
# label 过 complete
# label 海 complete
# label 好 complete
# label 号 complete
# label 和 complete
# label 何 complete
# label 合 complete
# label 很 complete
# label 候 complete
# label 后 complete
# label 乎 complete
# label 花 complete
# label 华 complete
# label 化 complete
# label 话 complete
# label 还 complete
# label 回 complete
# label 会 complete
# label 活 complete
# label 火 complete
# label 或 complete
# label 击 complete
# label 基 complete
# label 机 complete
# label 极 complete
# label 集 complete
# label 及 complete
# label 即 complete
# label 级 complete
# label 几 complete
# label 己 complete
# label 技 complete
# label 济 complete
# label 计 complete
# label 记 complete
# label 际 complete
# label 家 complete
# label 加 complete
# label 价 complete
# label 间 complete
# label 见 complete
# label 件 complete
# label 建 complete
# label 将 complete
# label 交 complete
# label 教 complete
# label 较 complete
# label 叫 complete
# label 接 complete
# label 结 complete
# label 解 complete
# label 界 complete
# label 金 complete
# label 今 complete
# label 仅 complete
# label 进 complete
# label 近 complete
# label 尽 complete
# label 精 complete
# label 经 complete
# label 究 complete
# label 九 complete
# label 就 complete
# label 局 complete
# label 据 complete
# label 具 complete
# label 觉 complete
# label 决 complete
# label 军 complete
# label 开 complete
# label 看 complete
# label 考 complete
# label 科 complete
# label 可 complete
# label 克 complete
# label 空 complete
# label 口 complete
# label 快 complete
# label 况 complete
# label 拉 complete
# label 来 complete
# label 老 complete
# label 类 complete
# label 离 complete
# label 理 complete
# label 李 complete
# label 里 complete
# label 历 complete
# label 利 complete
# label 立 complete
# label 力 complete
# label 联 complete
# label 连 complete
# label 两 complete
# label 量 complete
# label 了 complete
# label 列 complete
# label 林 complete
# label 领 complete
# label 另 complete
# label 令 complete
# label 流 complete
# label 六 complete
# label 路 complete
# label 论 complete
# label 罗 complete
# label 落 complete
# label 马 complete
# label 吗 complete
# label 满 complete
# label 么 complete
# label 没 complete
# label 每 complete
# label 美 complete
# label 门 complete
# label 们 complete
# label 面 complete
# label 民 complete
# label 明 complete
# label 名 complete
# label 命 complete
# label 目 complete
# label 那 complete
# label 南 complete
# label 难 complete
# label 呢 complete
# label 内 complete
# label 能 complete
# label 你 complete
# label 年 complete
# label 念 complete
# label 农 complete
# label 女 complete
# label 片 complete
# label 品 complete
# label 平 complete
# label 期 complete
# label 其 complete
# label 起 complete
# label 企 complete
# label 器 complete
# label 气 complete
# label 前 complete
# label 强 complete
# label 切 complete
# label 且 complete
# label 亲 complete
# label 青 complete
# label 轻 complete
# label 清 complete
# label 情 complete
# label 请 complete
# label 求 complete
# label 区 complete
# label 取 complete
# label 去 complete
# label 权 complete
# label 全 complete
# label 却 complete
# label 确 complete
# label 然 complete
# label 让 complete
# label 人 complete
# label 任 complete
# label 认 complete
# label 日 complete
# label 容 complete
# label 如 complete
# label 入 complete
# label 三 complete
# label 色 complete
# label 山 complete
# label 商 complete
# label 上 complete
# label 少 complete
# label 社 complete
# label 设 complete
# label 身 complete
# label 深 complete
# label 神 complete
# label 声 complete
# label 生 complete
# label 师 complete
# label 失 complete
# label 十 complete
# label 石 complete
# label 时 complete
# label 什 complete
# label 实 complete
# label 识 complete
# label 史 complete
# label 使 complete
# label 始 complete
# label 式 complete
# label 示 complete
# label 士 complete
# label 世 complete
# label 事 complete
# label 是 complete
# label 市 complete
# label 视 complete
# label 收 complete
# label 手 complete
# label 首 complete
# label 受 complete
# label 书 complete
# label 术 complete
# label 数 complete
# label 水 complete
# label 说 complete
# label 斯 complete
# label 思 complete
# label 司 complete
# label 死 complete
# label 四 complete
# label 似 complete
# label 算 complete
# label 随 complete
# label 所 complete
# label 他 complete
# label 它 complete
# label 她 complete
# label 台 complete
# label 太 complete
# label 谈 complete
# label 特 complete
# label 提 complete
# label 题 complete
# label 体 complete
# label 天 complete
# label 条 complete
# label 听 complete
# label 通 complete
# label 同 complete
# label 统 complete
# label 头 complete
# label 突 complete
# label 图 complete
# label 团 complete
# label 外 complete
# label 完 complete
# label 万 complete
# label 王 complete
# label 往 complete
# label 望 complete
# label 为 complete
# label 委 complete
# label 未 complete
# label 位 complete
# label 文 complete
# label 问 complete
# label 我 complete
# label 无 complete
# label 五 complete
# label 物 complete
# label 务 complete
# label 西 complete
# label 息 complete
# label 系 complete
# label 下 complete
# label 先 complete
# label 显 complete
# label 现 complete
# label 线 complete
# label 相 complete
# label 想 complete
# label 像 complete
# label 向 complete
# label 象 complete
# label 消 complete
# label 小 complete
# label 笑 complete
# label 些 complete
# label 写 complete
# label 新 complete
# label 心 complete
# label 信 complete
# label 形 complete
# label 行 complete
# label 性 complete
# label 需 complete
# label 须 complete
# label 许 complete
# label 选 complete
# label 学 complete
# label 亚 complete
# label 研 complete
# label 言 complete
# label 眼 complete
# label 样 complete
# label 要 complete
# label 也 complete
# label 业 complete
# label 一 complete
# label 医 complete
# label 已 complete
# label 以 complete
# label 易 complete
# label 意 complete
# label 义 complete
# label 议 complete
# label 因 complete
# label 引 complete
# label 英 complete
# label 应 complete
# label 影 complete
# label 用 complete
# label 由 complete
# label 有 complete
# label 又 complete
# label 于 complete
# label 与 complete
# label 语 complete
# label 元 complete
# label 原 complete
# label 员 complete
# label 远 complete
# label 院 complete
# label 约 complete
# label 越 complete
# label 月 complete
# label 运 complete
# label 再 complete
# label 在 complete
# label 早 complete
# label 造 complete
# label 则 complete
# label 怎 complete
# label 增 complete
# label 曾 complete
# label 展 complete
# label 战 complete
# label 张 complete
# label 找 complete
# label 照 complete
# label 者 complete
# label 这 complete
# label 真 complete
# label 争 complete
# label 整 complete
# label 正 complete
# label 政 complete
# label 证 complete
# label 支 complete
# label 知 complete
# label 之 complete
# label 直 complete
# label 指 complete
# label 只 complete
# label 至 complete
# label 制 complete
# label 质 complete
# label 治 complete
# label 中 complete
# label 种 complete
# label 重 complete
# label 周 complete
# label 主 complete
# label 住 complete
# label 注 complete
# label 专 complete
# label 转 complete
# label 装 complete
# label 准 complete
# label 着 complete
# label 资 complete
# label 子 complete
# label 自 complete
# label 字 complete
# label 总 complete
# label 走 complete
# label 组 complete
# label 最 complete
# label 做 complete
# label 作 complete
# label 阿 complete
# label 爱 complete
# label 安 complete
# label 吧 complete
# label 八 complete
# label 把 complete
# label 白 complete
# label 百 complete
# label 办 complete
# label 包 complete
# label 保 complete
# label 报 complete
# label 北 complete
# label 备 complete
# label 被 complete
# label 本 complete
# label 比 complete
# label 必 complete
# label 边 complete
# label 便 complete
# label 变 complete
# label 标 complete
# label 表 complete
# label 别 complete
# label 兵 complete
# label 病 complete
# label 并 complete
# label 不 complete
# label 布 complete
# label 步 complete
# label 部 complete
# label 才 complete
# label 查 complete
# label 产 complete
# label 场 complete
# label 常 complete
# label 长 complete
# label 车 complete
# label 称 complete
# label 城 complete
# label 成 complete
# label 程 complete
# label 吃 complete
# label 持 complete
# label 出 complete
# label 除 complete
# label 处 complete
# label 传 complete
# label 此 complete
# label 次 complete
# label 从 complete
# label 存 complete
# label 达 complete
# label 打 complete
# label 大 complete
# label 带 complete
# label 代 complete
# label 单 complete
# label 但 complete
# label 当 complete
# label 党 complete
# label 导 complete
# label 到 complete
# label 道 complete
# label 德 complete
# label 得 complete
# label 的 complete
# label 等 complete
# label 地 complete
# label 第 complete
# label 点 complete
# label 电 complete
# label 调 complete
# label 定 complete
# label 东 complete
# label 动 complete
# label 都 complete
# label 度 complete
# label 断 complete
# label 队 complete
# label 对 complete
# label 多 complete

# %%
x_test, y_test = extract_features_batch(test, normalization='P2DBMN')
x_train = x
y_train = y

print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))
# Out:
# 287695
# 287695
# 71936
# 71936

# %%
import numpy as np

# np.savez('features.npz',
#     X_train=x_train, y_train=np.array(y_train),
#     X_test=x_test,   y_test=np.array(y_test)
# )

data = np.load('features.npz', allow_pickle=True)
x_train, y_train = data['X_train'], data['y_train']
x_test,  y_test  = data['X_test'],  data['y_test']

print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))
# Out:
# 287695
# 287695
# 71936
# 71936

# %%
# !pip install scikit-learn 
import sys
# !{sys.executable} -m pip install scikit-learn
from sklearn.model_selection import train_test_split

#create validation set
x_train_sub, x_val, y_train_sub, y_val = train_test_split(
    x_train, y_train,
    test_size=0.1,      
    stratify=y_train    # keeps class proportions balanced
)
# Out:
# Requirement already satisfied: scikit-learn in ./miniforge3/lib/python3.12/site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in ./miniforge3/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.8.0 in ./miniforge3/lib/python3.12/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in ./miniforge3/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./miniforge3/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in ./venv/lib/python3.11/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in ./venv/lib/python3.11/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in ./venv/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: /Users/keanehaesle/venv/bin/python -m pip install --upgrade pip

# %%
# !{sys.executable} -m pip install torch
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(y_train)

x_tr = torch.tensor(x_train, dtype=torch.float32)
y_tr = torch.tensor(label_encoder.transform(y_train), dtype=torch.long)
x_v  = torch.tensor(x_val,   dtype=torch.float32)
y_v  = torch.tensor(label_encoder.transform(y_val),   dtype=torch.long)

loader = DataLoader(TensorDataset(x_tr, y_tr), batch_size=256, shuffle=True)

model     = nn.Linear(512, 500)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn   = nn.CrossEntropyLoss()

for epoch in range(20):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        optimizer.zero_grad()
        loss = loss_fn(model(xb), yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    model.eval()
    with torch.no_grad():
        val_preds = model(x_v).argmax(dim=1)
        val_acc   = (val_preds == y_v).float().mean().item()

    print(f"Epoch {epoch+1:2d}  loss={total_loss/len(loader):.4f}  val_acc={val_acc:.3f}")
# Out:
# Requirement already satisfied: torch in ./venv/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./venv/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.11/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.11/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: /Users/keanehaesle/venv/bin/python -m pip install --upgrade pip
# Epoch  1  loss=2.0147  val_acc=0.819
# Epoch  2  loss=0.8088  val_acc=0.847
# Epoch  3  loss=0.6539  val_acc=0.866
# Epoch  4  loss=0.5845  val_acc=0.871
# Epoch  5  loss=0.5400  val_acc=0.879
# Epoch  6  loss=0.5105  val_acc=0.884
# Epoch  7  loss=0.4888  val_acc=0.883
# Epoch  8  loss=0.4713  val_acc=0.891
# Epoch  9  loss=0.4578  val_acc=0.892
# Epoch 10  loss=0.4463  val_acc=0.892
# Epoch 11  loss=0.4353  val_acc=0.897
# Epoch 12  loss=0.4272  val_acc=0.899
# Epoch 13  loss=0.4190  val_acc=0.894
# Epoch 14  loss=0.4126  val_acc=0.899
# Epoch 15  loss=0.4060  val_acc=0.902
# Epoch 16  loss=0.4003  val_acc=0.903
# Epoch 17  loss=0.3947  val_acc=0.905
# Epoch 18  loss=0.3899  val_acc=0.905
# Epoch 19  loss=0.3856  val_acc=0.905
# Epoch 20  loss=0.3817  val_acc=0.907

# %%
x_te = torch.tensor(x_test, dtype=torch.float32)
y_te = torch.tensor(label_encoder.transform(y_test), dtype=torch.long)

model.eval()
with torch.no_grad():
    test_preds = model(x_te).argmax(dim=1)
    test_acc   = (test_preds == y_te).float().mean().item()

print(f"Test acc: {test_acc:.3f}")
# Out:
# Test acc: 0.863

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 21))
loss   = [2.0147,0.8088,0.6539,0.5845,0.5400,0.5105,0.4888,0.4713,0.4578,0.4463,
          0.4353,0.4272,0.4190,0.4126,0.4060,0.4003,0.3947,0.3899,0.3856,0.3817]
val_acc = [0.819,0.847,0.866,0.871,0.879,0.884,0.883,0.891,0.892,0.892,
           0.897,0.899,0.894,0.899,0.902,0.903,0.905,0.905,0.905,0.907]

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(epochs, loss, color='gray', linestyle='--', marker='o', ms=4, label='train loss')
ax1.set_xlabel('epoch')
ax1.set_ylabel('train loss', color='gray')
ax1.tick_params(axis='y', labelcolor='gray')

ax2 = ax1.twinx()
ax2.plot(epochs, val_acc, color='#1D9E75', marker='o', ms=4, label='val accuracy')
ax2.set_ylabel('val accuracy', color='#1D9E75')
ax2.tick_params(axis='y', labelcolor='#1D9E75')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0%}'))

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Training curves — logistic regression CASIA dataset')
plt.tight_layout()
plt.show()

# %%
import importlib
import Character_Synthetic_Dataset
importlib.reload(Character_Synthetic_Dataset)
from Character_Synthetic_Dataset import augment_dict

#goes through the dataset and perterbs every character so that it has incorrect order, missing strokes, and reversals

k = 1
augmented_train = augment_dict(train, k)
augmented_test = augment_dict(test, k)
# Out:
# 9574
# 而 done — 1152 samples from 576 original samples
# 儿 done — 1152 samples from 576 original samples
# 尔 done — 1152 samples from 576 original samples
# 二 done — 1148 samples from 574 original samples
# 发 done — 1152 samples from 576 original samples
# 法 done — 1150 samples from 575 original samples
# 反 done — 1152 samples from 576 original samples
# 方 done — 1152 samples from 576 original samples
# 放 done — 1146 samples from 573 original samples
# 非 done — 1152 samples from 576 original samples
# 飞 done — 1152 samples from 576 original samples
# 费 done — 1150 samples from 575 original samples
# 分 done — 1152 samples from 576 original samples
# 风 done — 1150 samples from 575 original samples
# 夫 done — 1148 samples from 574 original samples
# 服 done — 1150 samples from 575 original samples
# 府 done — 1150 samples from 575 original samples
# 复 done — 1152 samples from 576 original samples
# 该 done — 1152 samples from 576 original samples
# 改 done — 1152 samples from 576 original samples
# 干 done — 1152 samples from 576 original samples
# 感 done — 1152 samples from 576 original samples
# 高 done — 1152 samples from 576 original samples
# 告 done — 1152 samples from 576 original samples
# 格 done — 1150 samples from 575 original samples
# 个 done — 1152 samples from 576 original samples
# 各 done — 1152 samples from 576 original samples
# 给 done — 1136 samples from 568 original samples
# 根 done — 1152 samples from 576 original samples
# 更 done — 1152 samples from 576 original samples
# 工 done — 1152 samples from 576 original samples
# 功 done — 1152 samples from 576 original samples
# 公 done — 1152 samples from 576 original samples
# 共 done — 1148 samples from 574 original samples
# 关 done — 1150 samples from 575 original samples
# 官 done — 1150 samples from 575 original samples
# 观 done — 1150 samples from 575 original samples
# 管 done — 1152 samples from 576 original samples
# 光 done — 1150 samples from 575 original samples
# 广 done — 1152 samples from 576 original samples
# 规 done — 1152 samples from 576 original samples
# 国 done — 1152 samples from 576 original samples
# 果 done — 1152 samples from 576 original samples
# 过 done — 1152 samples from 576 original samples
# 海 done — 1152 samples from 576 original samples
# 好 done — 1150 samples from 575 original samples
# 号 done — 1150 samples from 575 original samples
# 和 done — 1152 samples from 576 original samples
# 何 done — 1152 samples from 576 original samples
# 合 done — 1152 samples from 576 original samples
# 很 done — 1152 samples from 576 original samples
# 候 done — 1152 samples from 576 original samples
# 后 done — 1152 samples from 576 original samples
# 乎 done — 1150 samples from 575 original samples
# 花 done — 1148 samples from 574 original samples
# 华 done — 1152 samples from 576 original samples
# 化 done — 1152 samples from 576 original samples
# 话 done — 1152 samples from 576 original samples
# 还 done — 1148 samples from 574 original samples
# 回 done — 1152 samples from 576 original samples
# 会 done — 1152 samples from 576 original samples
# 活 done — 1150 samples from 575 original samples
# 火 done — 1152 samples from 576 original samples
# 或 done — 1148 samples from 574 original samples
# 击 done — 1152 samples from 576 original samples
# 基 done — 1150 samples from 575 original samples
# 机 done — 1152 samples from 576 original samples
# 极 done — 1152 samples from 576 original samples
# 集 done — 1150 samples from 575 original samples
# 及 done — 1150 samples from 575 original samples
# 即 done — 1150 samples from 575 original samples
# 级 done — 1152 samples from 576 original samples
# 几 done — 1152 samples from 576 original samples
# 己 done — 1152 samples from 576 original samples
# 技 done — 1150 samples from 575 original samples
# 济 done — 1154 samples from 577 original samples
# 计 done — 1152 samples from 576 original samples
# 记 done — 1152 samples from 576 original samples
# 际 done — 1152 samples from 576 original samples
# 家 done — 1152 samples from 576 original samples
# 加 done — 1152 samples from 576 original samples
# 价 done — 1148 samples from 574 original samples
# 间 done — 1148 samples from 574 original samples
# 见 done — 1152 samples from 576 original samples
# 件 done — 1150 samples from 575 original samples
# 建 done — 1152 samples from 576 original samples
# 将 done — 1150 samples from 575 original samples
# 交 done — 1150 samples from 575 original samples
# 教 done — 1152 samples from 576 original samples
# 较 done — 1150 samples from 575 original samples
# 叫 done — 1152 samples from 576 original samples
# 接 done — 1152 samples from 576 original samples
# 结 done — 1152 samples from 576 original samples
# 解 done — 1152 samples from 576 original samples
# 界 done — 1152 samples from 576 original samples
# 金 done — 1150 samples from 575 original samples
# 今 done — 1146 samples from 573 original samples
# 仅 done — 1152 samples from 576 original samples
# 进 done — 1140 samples from 570 original samples
# 近 done — 1154 samples from 577 original samples
# 尽 done — 1152 samples from 576 original samples
# 精 done — 1152 samples from 576 original samples
# 经 done — 1150 samples from 575 original samples
# 究 done — 1150 samples from 575 original samples
# 九 done — 1152 samples from 576 original samples
# 就 done — 1152 samples from 576 original samples
# 局 done — 1152 samples from 576 original samples
# 据 done — 1152 samples from 576 original samples
# 具 done — 1152 samples from 576 original samples
# 觉 done — 1150 samples from 575 original samples
# 决 done — 1152 samples from 576 original samples
# 军 done — 1152 samples from 576 original samples
# 开 done — 1152 samples from 576 original samples
# 看 done — 1152 samples from 576 original samples
# 考 done — 1148 samples from 574 original samples
# 科 done — 1150 samples from 575 original samples
# 可 done — 1152 samples from 576 original samples
# 克 done — 1150 samples from 575 original samples
# 空 done — 1152 samples from 576 original samples
# 口 done — 1152 samples from 576 original samples
# 快 done — 1152 samples from 576 original samples
# 况 done — 1150 samples from 575 original samples
# 拉 done — 1148 samples from 574 original samples
# 来 done — 1152 samples from 576 original samples
# 老 done — 1150 samples from 575 original samples
# 类 done — 1152 samples from 576 original samples
# 离 done — 1150 samples from 575 original samples
# 理 done — 1152 samples from 576 original samples
# 李 done — 1148 samples from 574 original samples
# 里 done — 1152 samples from 576 original samples
# 历 done — 1152 samples from 576 original samples
# 利 done — 1150 samples from 575 original samples
# 立 done — 1152 samples from 576 original samples
# 力 done — 1152 samples from 576 original samples
# 联 done — 1150 samples from 575 original samples
# 连 done — 1152 samples from 576 original samples
# 两 done — 1150 samples from 575 original samples
# 量 done — 1150 samples from 575 original samples
# 了 done — 1148 samples from 574 original samples
# 列 done — 1152 samples from 576 original samples
# 林 done — 1152 samples from 576 original samples
# 领 done — 1150 samples from 575 original samples
# 另 done — 1148 samples from 574 original samples
# 令 done — 1152 samples from 576 original samples
# 流 done — 1152 samples from 576 original samples
# 六 done — 1150 samples from 575 original samples
# 路 done — 1150 samples from 575 original samples
# 论 done — 1152 samples from 576 original samples
# 罗 done — 1150 samples from 575 original samples
# 落 done — 1152 samples from 576 original samples
# 马 done — 1152 samples from 576 original samples
# 吗 done — 1146 samples from 573 original samples
# 满 done — 1150 samples from 575 original samples
# 么 done — 1146 samples from 573 original samples
# 没 done — 1152 samples from 576 original samples
# 每 done — 1152 samples from 576 original samples
# 美 done — 1150 samples from 575 original samples
# 门 done — 1150 samples from 575 original samples
# 们 done — 1150 samples from 575 original samples
# 面 done — 1152 samples from 576 original samples
# 民 done — 1152 samples from 576 original samples
# 明 done — 1150 samples from 575 original samples
# 名 done — 1152 samples from 576 original samples
# 命 done — 1152 samples from 576 original samples
# 目 done — 1152 samples from 576 original samples
# 那 done — 1152 samples from 576 original samples
# 南 done — 1152 samples from 576 original samples
# 难 done — 1150 samples from 575 original samples
# 呢 done — 1152 samples from 576 original samples
# 内 done — 1152 samples from 576 original samples
# 能 done — 1152 samples from 576 original samples
# 你 done — 1150 samples from 575 original samples
# 年 done — 1152 samples from 576 original samples
# 念 done — 1150 samples from 575 original samples
# 农 done — 1152 samples from 576 original samples
# 女 done — 1152 samples from 576 original samples
# 片 done — 1152 samples from 576 original samples
# 品 done — 1152 samples from 576 original samples
# 平 done — 1152 samples from 576 original samples
# 期 done — 1150 samples from 575 original samples
# 其 done — 1150 samples from 575 original samples
# 起 done — 1152 samples from 576 original samples
# 企 done — 1150 samples from 575 original samples
# 器 done — 1152 samples from 576 original samples
# 气 done — 1152 samples from 576 original samples
# 前 done — 1150 samples from 575 original samples
# 强 done — 1148 samples from 574 original samples
# 切 done — 1150 samples from 575 original samples
# 且 done — 1152 samples from 576 original samples
# 亲 done — 1152 samples from 576 original samples
# 青 done — 1152 samples from 576 original samples
# 轻 done — 1150 samples from 575 original samples
# 清 done — 1152 samples from 576 original samples
# 情 done — 1148 samples from 574 original samples
# 请 done — 1148 samples from 574 original samples
# 求 done — 1150 samples from 575 original samples
# 区 done — 1152 samples from 576 original samples
# 取 done — 1148 samples from 574 original samples
# 去 done — 1152 samples from 576 original samples
# 权 done — 1152 samples from 576 original samples
# 全 done — 1152 samples from 576 original samples
# 却 done — 1148 samples from 574 original samples
# 确 done — 1152 samples from 576 original samples
# 然 done — 1150 samples from 575 original samples
# 让 done — 1144 samples from 572 original samples
# 人 done — 1152 samples from 576 original samples
# 任 done — 1152 samples from 576 original samples
# 认 done — 1150 samples from 575 original samples
# 日 done — 1152 samples from 576 original samples
# 容 done — 1152 samples from 576 original samples
# 如 done — 1150 samples from 575 original samples
# 入 done — 1150 samples from 575 original samples
# 三 done — 1152 samples from 576 original samples
# 色 done — 1152 samples from 576 original samples
# 山 done — 1152 samples from 576 original samples
# 商 done — 1146 samples from 573 original samples
# 上 done — 1150 samples from 575 original samples
# 少 done — 1152 samples from 576 original samples
# 社 done — 1146 samples from 573 original samples
# 设 done — 1150 samples from 575 original samples
# 身 done — 1150 samples from 575 original samples
# 深 done — 1152 samples from 576 original samples
# 神 done — 1152 samples from 576 original samples
# 声 done — 1152 samples from 576 original samples
# 生 done — 1152 samples from 576 original samples
# 师 done — 1150 samples from 575 original samples
# 失 done — 1152 samples from 576 original samples
# 十 done — 1152 samples from 576 original samples
# 石 done — 1150 samples from 575 original samples
# 时 done — 1152 samples from 576 original samples
# 什 done — 1144 samples from 572 original samples
# 实 done — 1150 samples from 575 original samples
# 识 done — 1152 samples from 576 original samples
# 史 done — 1152 samples from 576 original samples
# 使 done — 1146 samples from 573 original samples
# 始 done — 1150 samples from 575 original samples
# 式 done — 1142 samples from 571 original samples
# 示 done — 1152 samples from 576 original samples
# 士 done — 1152 samples from 576 original samples
# 世 done — 1152 samples from 576 original samples
# 事 done — 1150 samples from 575 original samples
# 是 done — 1150 samples from 575 original samples
# 市 done — 1152 samples from 576 original samples
# 视 done — 1150 samples from 575 original samples
# 收 done — 1152 samples from 576 original samples
# 手 done — 1152 samples from 576 original samples
# 首 done — 1152 samples from 576 original samples
# 受 done — 1148 samples from 574 original samples
# 书 done — 1148 samples from 574 original samples
# 术 done — 1150 samples from 575 original samples
# 数 done — 1148 samples from 574 original samples
# 水 done — 1152 samples from 576 original samples
# 说 done — 1150 samples from 575 original samples
# 斯 done — 1152 samples from 576 original samples
# 思 done — 1150 samples from 575 original samples
# 司 done — 1152 samples from 576 original samples
# 死 done — 1150 samples from 575 original samples
# 四 done — 1152 samples from 576 original samples
# 似 done — 1152 samples from 576 original samples
# 算 done — 1152 samples from 576 original samples
# 随 done — 1152 samples from 576 original samples
# 所 done — 1152 samples from 576 original samples
# 他 done — 1152 samples from 576 original samples
# 它 done — 1150 samples from 575 original samples
# 她 done — 1150 samples from 575 original samples
# 台 done — 1152 samples from 576 original samples
# 太 done — 1152 samples from 576 original samples
# 谈 done — 1152 samples from 576 original samples
# 特 done — 1150 samples from 575 original samples
# 提 done — 1150 samples from 575 original samples
# 题 done — 1148 samples from 574 original samples
# 体 done — 1152 samples from 576 original samples
# 天 done — 1148 samples from 574 original samples
# 条 done — 1150 samples from 575 original samples
# 听 done — 1152 samples from 576 original samples
# 通 done — 1152 samples from 576 original samples
# 同 done — 1152 samples from 576 original samples
# 统 done — 1150 samples from 575 original samples
# 头 done — 1152 samples from 576 original samples
# 突 done — 1152 samples from 576 original samples
# 图 done — 1150 samples from 575 original samples
# 团 done — 1152 samples from 576 original samples
# 外 done — 1150 samples from 575 original samples
# 完 done — 1152 samples from 576 original samples
# 万 done — 1148 samples from 574 original samples
# 王 done — 1152 samples from 576 original samples
# 往 done — 1152 samples from 576 original samples
# 望 done — 1152 samples from 576 original samples
# 为 done — 1146 samples from 573 original samples
# 委 done — 1150 samples from 575 original samples
# 未 done — 1150 samples from 575 original samples
# 位 done — 1152 samples from 576 original samples
# 文 done — 1148 samples from 574 original samples
# 问 done — 1150 samples from 575 original samples
# 我 done — 1152 samples from 576 original samples
# 无 done — 1150 samples from 575 original samples
# 五 done — 1152 samples from 576 original samples
# 物 done — 1150 samples from 575 original samples
# 务 done — 1150 samples from 575 original samples
# 西 done — 1150 samples from 575 original samples
# 息 done — 1148 samples from 574 original samples
# 系 done — 1152 samples from 576 original samples
# 下 done — 1152 samples from 576 original samples
# 先 done — 1152 samples from 576 original samples
# 显 done — 1152 samples from 576 original samples
# 现 done — 1152 samples from 576 original samples
# 线 done — 1150 samples from 575 original samples
# 相 done — 1152 samples from 576 original samples
# 想 done — 1152 samples from 576 original samples
# 像 done — 1152 samples from 576 original samples
# 向 done — 1152 samples from 576 original samples
# 象 done — 1152 samples from 576 original samples
# 消 done — 1150 samples from 575 original samples
# 小 done — 1152 samples from 576 original samples
# 笑 done — 1152 samples from 576 original samples
# 些 done — 1148 samples from 574 original samples
# 写 done — 1150 samples from 575 original samples
# 新 done — 1150 samples from 575 original samples
# 心 done — 1152 samples from 576 original samples
# 信 done — 1150 samples from 575 original samples
# 形 done — 1152 samples from 576 original samples
# 行 done — 1152 samples from 576 original samples
# 性 done — 1146 samples from 573 original samples
# 需 done — 1152 samples from 576 original samples
# 须 done — 1152 samples from 576 original samples
# 许 done — 1154 samples from 577 original samples
# 选 done — 1150 samples from 575 original samples
# 学 done — 1152 samples from 576 original samples
# 亚 done — 1152 samples from 576 original samples
# 研 done — 1150 samples from 575 original samples
# 言 done — 1152 samples from 576 original samples
# 眼 done — 1152 samples from 576 original samples
# 样 done — 1138 samples from 569 original samples
# 要 done — 1154 samples from 577 original samples
# 也 done — 1152 samples from 576 original samples
# 业 done — 1152 samples from 576 original samples
# 一 done — 1152 samples from 576 original samples
# 医 done — 1152 samples from 576 original samples
# 已 done — 1152 samples from 576 original samples
# 以 done — 1152 samples from 576 original samples
# 易 done — 1150 samples from 575 original samples
# 意 done — 1144 samples from 572 original samples
# 义 done — 1152 samples from 576 original samples
# 议 done — 1152 samples from 576 original samples
# 因 done — 1150 samples from 575 original samples
# 引 done — 1152 samples from 576 original samples
# 英 done — 1152 samples from 576 original samples
# 应 done — 1150 samples from 575 original samples
# 影 done — 1150 samples from 575 original samples
# 用 done — 1152 samples from 576 original samples
# 由 done — 1152 samples from 576 original samples
# 有 done — 1152 samples from 576 original samples
# 又 done — 1150 samples from 575 original samples
# 于 done — 1150 samples from 575 original samples
# 与 done — 1152 samples from 576 original samples
# 语 done — 1150 samples from 575 original samples
# 元 done — 1150 samples from 575 original samples
# 原 done — 1148 samples from 574 original samples
# 员 done — 1152 samples from 576 original samples
# 远 done — 1152 samples from 576 original samples
# 院 done — 1152 samples from 576 original samples
# 约 done — 1152 samples from 576 original samples
# 越 done — 1150 samples from 575 original samples
# 月 done — 1152 samples from 576 original samples
# 运 done — 1150 samples from 575 original samples
# 再 done — 1150 samples from 575 original samples
# 在 done — 1152 samples from 576 original samples
# 早 done — 1150 samples from 575 original samples
# 造 done — 1150 samples from 575 original samples
# 则 done — 1152 samples from 576 original samples
# 怎 done — 1150 samples from 575 original samples
# 增 done — 1150 samples from 575 original samples
# 曾 done — 1152 samples from 576 original samples
# 展 done — 1148 samples from 574 original samples
# 战 done — 1152 samples from 576 original samples
# 张 done — 1152 samples from 576 original samples
# 找 done — 1150 samples from 575 original samples
# 照 done — 1152 samples from 576 original samples
# 者 done — 1150 samples from 575 original samples
# 这 done — 1150 samples from 575 original samples
# 真 done — 1152 samples from 576 original samples
# 争 done — 1152 samples from 576 original samples
# 整 done — 1150 samples from 575 original samples
# 正 done — 1152 samples from 576 original samples
# 政 done — 1152 samples from 576 original samples
# 证 done — 1152 samples from 576 original samples
# 支 done — 1150 samples from 575 original samples
# 知 done — 1150 samples from 575 original samples
# 之 done — 1152 samples from 576 original samples
# 直 done — 1150 samples from 575 original samples
# 指 done — 1152 samples from 576 original samples
# 只 done — 1152 samples from 576 original samples
# 至 done — 1152 samples from 576 original samples
# 制 done — 1150 samples from 575 original samples
# 质 done — 1152 samples from 576 original samples
# 治 done — 1150 samples from 575 original samples
# 中 done — 1150 samples from 575 original samples
# 种 done — 1150 samples from 575 original samples
# 重 done — 1150 samples from 575 original samples
# 周 done — 1146 samples from 573 original samples
# 主 done — 1152 samples from 576 original samples
# 住 done — 1150 samples from 575 original samples
# 注 done — 1152 samples from 576 original samples
# 专 done — 1152 samples from 576 original samples
# 转 done — 1152 samples from 576 original samples
# 装 done — 1150 samples from 575 original samples
# 准 done — 1150 samples from 575 original samples
# 着 done — 1152 samples from 576 original samples
# 资 done — 1148 samples from 574 original samples
# 子 done — 1152 samples from 576 original samples
# 自 done — 1152 samples from 576 original samples
# 字 done — 1152 samples from 576 original samples
# 总 done — 1146 samples from 573 original samples
# 走 done — 1152 samples from 576 original samples
# 组 done — 1150 samples from 575 original samples
# 最 done — 1148 samples from 574 original samples
# 做 done — 1152 samples from 576 original samples
# 作 done — 1152 samples from 576 original samples
# 阿 done — 1148 samples from 574 original samples
# 爱 done — 1150 samples from 575 original samples
# 安 done — 1150 samples from 575 original samples
# 吧 done — 1152 samples from 576 original samples
# 八 done — 1148 samples from 574 original samples
# 把 done — 1152 samples from 576 original samples
# 白 done — 1150 samples from 575 original samples
# 百 done — 1152 samples from 576 original samples
# 办 done — 1150 samples from 575 original samples
# 包 done — 1150 samples from 575 original samples
# 保 done — 1146 samples from 573 original samples
# 报 done — 1152 samples from 576 original samples
# 北 done — 1148 samples from 574 original samples
# 备 done — 1150 samples from 575 original samples
# 被 done — 1152 samples from 576 original samples
# 本 done — 1152 samples from 576 original samples
# 比 done — 1152 samples from 576 original samples
# 必 done — 1152 samples from 576 original samples
# 边 done — 1152 samples from 576 original samples
# 便 done — 1152 samples from 576 original samples
# 变 done — 1152 samples from 576 original samples
# 标 done — 1152 samples from 576 original samples
# 表 done — 1152 samples from 576 original samples
# 别 done — 1152 samples from 576 original samples
# 兵 done — 1152 samples from 576 original samples
# 病 done — 1152 samples from 576 original samples
# 并 done — 1152 samples from 576 original samples
# 不 done — 1152 samples from 576 original samples
# 布 done — 1152 samples from 576 original samples
# 步 done — 1152 samples from 576 original samples
# 部 done — 1152 samples from 576 original samples
# 才 done — 1152 samples from 576 original samples
# 查 done — 1150 samples from 575 original samples
# 产 done — 1150 samples from 575 original samples
# 场 done — 1150 samples from 575 original samples
# 常 done — 1150 samples from 575 original samples
# 长 done — 1152 samples from 576 original samples
# 车 done — 1150 samples from 575 original samples
# 称 done — 1152 samples from 576 original samples
# 城 done — 1152 samples from 576 original samples
# 成 done — 1152 samples from 576 original samples
# 程 done — 1152 samples from 576 original samples
# 吃 done — 1150 samples from 575 original samples
# 持 done — 1152 samples from 576 original samples
# 出 done — 1150 samples from 575 original samples
# 除 done — 1152 samples from 576 original samples
# 处 done — 1150 samples from 575 original samples
# 传 done — 1150 samples from 575 original samples
# 此 done — 1152 samples from 576 original samples
# 次 done — 1152 samples from 576 original samples
# 从 done — 1146 samples from 573 original samples
# 存 done — 1148 samples from 574 original samples
# 达 done — 1152 samples from 576 original samples
# 打 done — 1152 samples from 576 original samples
# 大 done — 1152 samples from 576 original samples
# 带 done — 1150 samples from 575 original samples
# 代 done — 1150 samples from 575 original samples
# 单 done — 1150 samples from 575 original samples
# 但 done — 1152 samples from 576 original samples
# 当 done — 1152 samples from 576 original samples
# 党 done — 1152 samples from 576 original samples
# 导 done — 1148 samples from 574 original samples
# 到 done — 1152 samples from 576 original samples
# 道 done — 1148 samples from 574 original samples
# 德 done — 1150 samples from 575 original samples
# 得 done — 1150 samples from 575 original samples
# 的 done — 1152 samples from 576 original samples
# 等 done — 1150 samples from 575 original samples
# 地 done — 1150 samples from 575 original samples
# 第 done — 1152 samples from 576 original samples
# 点 done — 1152 samples from 576 original samples
# 电 done — 1152 samples from 576 original samples
# 调 done — 1152 samples from 576 original samples
# 定 done — 1152 samples from 576 original samples
# 东 done — 1152 samples from 576 original samples
# 动 done — 1150 samples from 575 original samples
# 都 done — 1152 samples from 576 original samples
# 度 done — 1150 samples from 575 original samples
# 断 done — 1146 samples from 573 original samples
# 队 done — 1152 samples from 576 original samples
# 对 done — 1144 samples from 572 original samples
# 多 done — 1150 samples from 575 original samples
# 意 done — 288 samples from 144 original samples
# 义 done — 288 samples from 144 original samples
# 议 done — 288 samples from 144 original samples
# 因 done — 290 samples from 145 original samples
# 引 done — 288 samples from 144 original samples
# 英 done — 288 samples from 144 original samples
# 应 done — 288 samples from 144 original samples
# 影 done — 288 samples from 144 original samples
# 用 done — 288 samples from 144 original samples
# 由 done — 288 samples from 144 original samples
# 有 done — 288 samples from 144 original samples
# 又 done — 288 samples from 144 original samples
# 于 done — 288 samples from 144 original samples
# 与 done — 288 samples from 144 original samples
# 语 done — 286 samples from 143 original samples
# 元 done — 288 samples from 144 original samples
# 原 done — 286 samples from 143 original samples
# 员 done — 288 samples from 144 original samples
# 远 done — 288 samples from 144 original samples
# 院 done — 288 samples from 144 original samples
# 约 done — 288 samples from 144 original samples
# 越 done — 282 samples from 141 original samples
# 月 done — 288 samples from 144 original samples
# 运 done — 288 samples from 144 original samples
# 再 done — 286 samples from 143 original samples
# 在 done — 288 samples from 144 original samples
# 早 done — 288 samples from 144 original samples
# 造 done — 286 samples from 143 original samples
# 则 done — 288 samples from 144 original samples
# 怎 done — 288 samples from 144 original samples
# 增 done — 286 samples from 143 original samples
# 曾 done — 288 samples from 144 original samples
# 展 done — 288 samples from 144 original samples
# 战 done — 286 samples from 143 original samples
# 张 done — 288 samples from 144 original samples
# 找 done — 288 samples from 144 original samples
# 照 done — 288 samples from 144 original samples
# 者 done — 288 samples from 144 original samples
# 这 done — 288 samples from 144 original samples
# 真 done — 286 samples from 143 original samples
# 争 done — 288 samples from 144 original samples
# 整 done — 286 samples from 143 original samples
# 正 done — 288 samples from 144 original samples
# 政 done — 288 samples from 144 original samples
# 证 done — 288 samples from 144 original samples
# 支 done — 288 samples from 144 original samples
# 知 done — 286 samples from 143 original samples
# 之 done — 288 samples from 144 original samples
# 直 done — 288 samples from 144 original samples
# 指 done — 288 samples from 144 original samples
# 只 done — 288 samples from 144 original samples
# 至 done — 288 samples from 144 original samples
# 制 done — 288 samples from 144 original samples
# 质 done — 288 samples from 144 original samples
# 治 done — 290 samples from 145 original samples
# 中 done — 288 samples from 144 original samples
# 种 done — 288 samples from 144 original samples
# 重 done — 288 samples from 144 original samples
# 周 done — 288 samples from 144 original samples
# 主 done — 288 samples from 144 original samples
# 住 done — 288 samples from 144 original samples
# 注 done — 288 samples from 144 original samples
# 专 done — 288 samples from 144 original samples
# 转 done — 288 samples from 144 original samples
# 装 done — 288 samples from 144 original samples
# 准 done — 288 samples from 144 original samples
# 着 done — 288 samples from 144 original samples
# 资 done — 288 samples from 144 original samples
# 子 done — 288 samples from 144 original samples
# 自 done — 288 samples from 144 original samples
# 字 done — 286 samples from 143 original samples
# 总 done — 286 samples from 143 original samples
# 走 done — 288 samples from 144 original samples
# 组 done — 286 samples from 143 original samples
# 最 done — 288 samples from 144 original samples
# 做 done — 288 samples from 144 original samples
# 作 done — 288 samples from 144 original samples
# 阿 done — 288 samples from 144 original samples
# 爱 done — 286 samples from 143 original samples
# 安 done — 288 samples from 144 original samples
# 吧 done — 288 samples from 144 original samples
# 八 done — 288 samples from 144 original samples
# 把 done — 288 samples from 144 original samples
# 白 done — 288 samples from 144 original samples
# 百 done — 288 samples from 144 original samples
# 办 done — 288 samples from 144 original samples
# 包 done — 288 samples from 144 original samples
# 保 done — 286 samples from 143 original samples
# 报 done — 288 samples from 144 original samples
# 北 done — 288 samples from 144 original samples
# 备 done — 288 samples from 144 original samples
# 被 done — 288 samples from 144 original samples
# 本 done — 288 samples from 144 original samples
# 比 done — 288 samples from 144 original samples
# 必 done — 286 samples from 143 original samples
# 边 done — 288 samples from 144 original samples
# 便 done — 288 samples from 144 original samples
# 变 done — 288 samples from 144 original samples
# 标 done — 288 samples from 144 original samples
# 表 done — 288 samples from 144 original samples
# 别 done — 286 samples from 143 original samples
# 兵 done — 288 samples from 144 original samples
# 病 done — 288 samples from 144 original samples
# 并 done — 288 samples from 144 original samples
# 不 done — 288 samples from 144 original samples
# 布 done — 288 samples from 144 original samples
# 步 done — 288 samples from 144 original samples
# 部 done — 288 samples from 144 original samples
# 才 done — 288 samples from 144 original samples
# 查 done — 288 samples from 144 original samples
# 产 done — 286 samples from 143 original samples
# 场 done — 284 samples from 142 original samples
# 常 done — 288 samples from 144 original samples
# 长 done — 288 samples from 144 original samples
# 车 done — 288 samples from 144 original samples
# 称 done — 288 samples from 144 original samples
# 城 done — 288 samples from 144 original samples
# 成 done — 288 samples from 144 original samples
# 程 done — 288 samples from 144 original samples
# 吃 done — 288 samples from 144 original samples
# 持 done — 288 samples from 144 original samples
# 出 done — 288 samples from 144 original samples
# 除 done — 288 samples from 144 original samples
# 处 done — 288 samples from 144 original samples
# 传 done — 288 samples from 144 original samples
# 此 done — 288 samples from 144 original samples
# 次 done — 288 samples from 144 original samples
# 从 done — 288 samples from 144 original samples
# 存 done — 288 samples from 144 original samples
# 达 done — 288 samples from 144 original samples
# 打 done — 286 samples from 143 original samples
# 大 done — 288 samples from 144 original samples
# 带 done — 288 samples from 144 original samples
# 代 done — 286 samples from 143 original samples
# 单 done — 288 samples from 144 original samples
# 但 done — 288 samples from 144 original samples
# 当 done — 288 samples from 144 original samples
# 党 done — 288 samples from 144 original samples
# 导 done — 288 samples from 144 original samples
# 到 done — 288 samples from 144 original samples
# 道 done — 288 samples from 144 original samples
# 德 done — 288 samples from 144 original samples
# 得 done — 288 samples from 144 original samples
# 的 done — 288 samples from 144 original samples
# 等 done — 288 samples from 144 original samples
# 地 done — 288 samples from 144 original samples
# 第 done — 286 samples from 143 original samples
# 点 done — 286 samples from 143 original samples
# 电 done — 286 samples from 143 original samples
# 调 done — 288 samples from 144 original samples
# 定 done — 288 samples from 144 original samples
# 东 done — 288 samples from 144 original samples
# 动 done — 288 samples from 144 original samples
# 都 done — 288 samples from 144 original samples
# 度 done — 288 samples from 144 original samples
# 断 done — 288 samples from 144 original samples
# 队 done — 288 samples from 144 original samples
# 对 done — 288 samples from 144 original samples
# 多 done — 288 samples from 144 original samples
# 而 done — 288 samples from 144 original samples
# 儿 done — 288 samples from 144 original samples
# 尔 done — 288 samples from 144 original samples
# 二 done — 286 samples from 143 original samples
# 发 done — 288 samples from 144 original samples
# 法 done — 288 samples from 144 original samples
# 反 done — 288 samples from 144 original samples
# 方 done — 288 samples from 144 original samples
# 放 done — 288 samples from 144 original samples
# 非 done — 288 samples from 144 original samples
# 飞 done — 288 samples from 144 original samples
# 费 done — 288 samples from 144 original samples
# 分 done — 288 samples from 144 original samples
# 风 done — 288 samples from 144 original samples
# 夫 done — 288 samples from 144 original samples
# 服 done — 288 samples from 144 original samples
# 府 done — 288 samples from 144 original samples
# 复 done — 288 samples from 144 original samples
# 该 done — 288 samples from 144 original samples
# 改 done — 286 samples from 143 original samples
# 干 done — 288 samples from 144 original samples
# 感 done — 288 samples from 144 original samples
# 高 done — 288 samples from 144 original samples
# 告 done — 288 samples from 144 original samples
# 格 done — 288 samples from 144 original samples
# 个 done — 288 samples from 144 original samples
# 各 done — 288 samples from 144 original samples
# 给 done — 288 samples from 144 original samples
# 根 done — 288 samples from 144 original samples
# 更 done — 288 samples from 144 original samples
# 工 done — 286 samples from 143 original samples
# 功 done — 288 samples from 144 original samples
# 公 done — 288 samples from 144 original samples
# 共 done — 288 samples from 144 original samples
# 关 done — 286 samples from 143 original samples
# 官 done — 286 samples from 143 original samples
# 观 done — 288 samples from 144 original samples
# 管 done — 288 samples from 144 original samples
# 光 done — 288 samples from 144 original samples
# 广 done — 288 samples from 144 original samples
# 规 done — 288 samples from 144 original samples
# 国 done — 288 samples from 144 original samples
# 果 done — 288 samples from 144 original samples
# 过 done — 288 samples from 144 original samples
# 海 done — 288 samples from 144 original samples
# 好 done — 286 samples from 143 original samples
# 号 done — 288 samples from 144 original samples
# 和 done — 288 samples from 144 original samples
# 何 done — 288 samples from 144 original samples
# 合 done — 288 samples from 144 original samples
# 很 done — 288 samples from 144 original samples
# 候 done — 288 samples from 144 original samples
# 后 done — 288 samples from 144 original samples
# 乎 done — 288 samples from 144 original samples
# 花 done — 288 samples from 144 original samples
# 华 done — 288 samples from 144 original samples
# 化 done — 288 samples from 144 original samples
# 话 done — 288 samples from 144 original samples
# 还 done — 288 samples from 144 original samples
# 回 done — 288 samples from 144 original samples
# 会 done — 288 samples from 144 original samples
# 活 done — 288 samples from 144 original samples
# 火 done — 288 samples from 144 original samples
# 或 done — 288 samples from 144 original samples
# 击 done — 288 samples from 144 original samples
# 基 done — 288 samples from 144 original samples
# 机 done — 288 samples from 144 original samples
# 极 done — 288 samples from 144 original samples
# 集 done — 288 samples from 144 original samples
# 及 done — 288 samples from 144 original samples
# 即 done — 288 samples from 144 original samples
# 级 done — 288 samples from 144 original samples
# 几 done — 288 samples from 144 original samples
# 己 done — 288 samples from 144 original samples
# 技 done — 288 samples from 144 original samples
# 济 done — 288 samples from 144 original samples
# 计 done — 288 samples from 144 original samples
# 记 done — 288 samples from 144 original samples
# 际 done — 288 samples from 144 original samples
# 家 done — 288 samples from 144 original samples
# 加 done — 288 samples from 144 original samples
# 价 done — 288 samples from 144 original samples
# 间 done — 286 samples from 143 original samples
# 见 done — 288 samples from 144 original samples
# 件 done — 288 samples from 144 original samples
# 建 done — 288 samples from 144 original samples
# 将 done — 288 samples from 144 original samples
# 交 done — 288 samples from 144 original samples
# 教 done — 288 samples from 144 original samples
# 较 done — 288 samples from 144 original samples
# 叫 done — 288 samples from 144 original samples
# 接 done — 288 samples from 144 original samples
# 结 done — 286 samples from 143 original samples
# 解 done — 288 samples from 144 original samples
# 界 done — 288 samples from 144 original samples
# 金 done — 288 samples from 144 original samples
# 今 done — 288 samples from 144 original samples
# 仅 done — 288 samples from 144 original samples
# 进 done — 288 samples from 144 original samples
# 近 done — 288 samples from 144 original samples
# 尽 done — 288 samples from 144 original samples
# 精 done — 288 samples from 144 original samples
# 经 done — 288 samples from 144 original samples
# 究 done — 288 samples from 144 original samples
# 九 done — 288 samples from 144 original samples
# 就 done — 288 samples from 144 original samples
# 局 done — 288 samples from 144 original samples
# 据 done — 288 samples from 144 original samples
# 具 done — 286 samples from 143 original samples
# 觉 done — 288 samples from 144 original samples
# 决 done — 288 samples from 144 original samples
# 军 done — 288 samples from 144 original samples
# 开 done — 288 samples from 144 original samples
# 看 done — 288 samples from 144 original samples
# 考 done — 288 samples from 144 original samples
# 科 done — 288 samples from 144 original samples
# 可 done — 286 samples from 143 original samples
# 克 done — 288 samples from 144 original samples
# 空 done — 288 samples from 144 original samples
# 口 done — 288 samples from 144 original samples
# 快 done — 286 samples from 143 original samples
# 况 done — 288 samples from 144 original samples
# 拉 done — 290 samples from 145 original samples
# 来 done — 288 samples from 144 original samples
# 老 done — 286 samples from 143 original samples
# 类 done — 288 samples from 144 original samples
# 离 done — 288 samples from 144 original samples
# 理 done — 288 samples from 144 original samples
# 李 done — 288 samples from 144 original samples
# 里 done — 288 samples from 144 original samples
# 历 done — 288 samples from 144 original samples
# 利 done — 288 samples from 144 original samples
# 立 done — 288 samples from 144 original samples
# 力 done — 288 samples from 144 original samples
# 联 done — 288 samples from 144 original samples
# 连 done — 288 samples from 144 original samples
# 两 done — 288 samples from 144 original samples
# 量 done — 288 samples from 144 original samples
# 了 done — 288 samples from 144 original samples
# 列 done — 288 samples from 144 original samples
# 林 done — 288 samples from 144 original samples
# 领 done — 286 samples from 143 original samples
# 另 done — 288 samples from 144 original samples
# 令 done — 288 samples from 144 original samples
# 流 done — 288 samples from 144 original samples
# 六 done — 288 samples from 144 original samples
# 路 done — 288 samples from 144 original samples
# 论 done — 288 samples from 144 original samples
# 罗 done — 288 samples from 144 original samples
# 落 done — 288 samples from 144 original samples
# 马 done — 290 samples from 145 original samples
# 吗 done — 288 samples from 144 original samples
# 满 done — 288 samples from 144 original samples
# 么 done — 288 samples from 144 original samples
# 没 done — 286 samples from 143 original samples
# 每 done — 288 samples from 144 original samples
# 美 done — 288 samples from 144 original samples
# 门 done — 288 samples from 144 original samples
# 们 done — 286 samples from 143 original samples
# 面 done — 288 samples from 144 original samples
# 民 done — 288 samples from 144 original samples
# 明 done — 288 samples from 144 original samples
# 名 done — 288 samples from 144 original samples
# 命 done — 288 samples from 144 original samples
# 目 done — 288 samples from 144 original samples
# 那 done — 288 samples from 144 original samples
# 南 done — 288 samples from 144 original samples
# 难 done — 288 samples from 144 original samples
# 呢 done — 288 samples from 144 original samples
# 内 done — 288 samples from 144 original samples
# 能 done — 288 samples from 144 original samples
# 你 done — 288 samples from 144 original samples
# 年 done — 288 samples from 144 original samples
# 念 done — 288 samples from 144 original samples
# 农 done — 288 samples from 144 original samples
# 女 done — 288 samples from 144 original samples
# 片 done — 288 samples from 144 original samples
# 品 done — 288 samples from 144 original samples
# 平 done — 288 samples from 144 original samples
# 期 done — 288 samples from 144 original samples
# 其 done — 288 samples from 144 original samples
# 起 done — 288 samples from 144 original samples
# 企 done — 288 samples from 144 original samples
# 器 done — 288 samples from 144 original samples
# 气 done — 288 samples from 144 original samples
# 前 done — 288 samples from 144 original samples
# 强 done — 288 samples from 144 original samples
# 切 done — 288 samples from 144 original samples
# 且 done — 288 samples from 144 original samples
# 亲 done — 288 samples from 144 original samples
# 青 done — 288 samples from 144 original samples
# 轻 done — 288 samples from 144 original samples
# 清 done — 288 samples from 144 original samples
# 情 done — 288 samples from 144 original samples
# 请 done — 288 samples from 144 original samples
# 求 done — 288 samples from 144 original samples
# 区 done — 288 samples from 144 original samples
# 取 done — 288 samples from 144 original samples
# 去 done — 288 samples from 144 original samples
# 权 done — 288 samples from 144 original samples
# 全 done — 288 samples from 144 original samples
# 却 done — 288 samples from 144 original samples
# 确 done — 288 samples from 144 original samples
# 然 done — 288 samples from 144 original samples
# 让 done — 286 samples from 143 original samples
# 人 done — 288 samples from 144 original samples
# 任 done — 288 samples from 144 original samples
# 认 done — 288 samples from 144 original samples
# 日 done — 288 samples from 144 original samples
# 容 done — 286 samples from 143 original samples
# 如 done — 286 samples from 143 original samples
# 入 done — 288 samples from 144 original samples
# 三 done — 288 samples from 144 original samples
# 色 done — 288 samples from 144 original samples
# 山 done — 288 samples from 144 original samples
# 商 done — 288 samples from 144 original samples
# 上 done — 288 samples from 144 original samples
# 少 done — 288 samples from 144 original samples
# 社 done — 288 samples from 144 original samples
# 设 done — 288 samples from 144 original samples
# 身 done — 288 samples from 144 original samples
# 深 done — 288 samples from 144 original samples
# 神 done — 286 samples from 143 original samples
# 声 done — 288 samples from 144 original samples
# 生 done — 288 samples from 144 original samples
# 师 done — 288 samples from 144 original samples
# 失 done — 288 samples from 144 original samples
# 十 done — 288 samples from 144 original samples
# 石 done — 288 samples from 144 original samples
# 时 done — 288 samples from 144 original samples
# 什 done — 288 samples from 144 original samples
# 实 done — 288 samples from 144 original samples
# 识 done — 288 samples from 144 original samples
# 史 done — 288 samples from 144 original samples
# 使 done — 288 samples from 144 original samples
# 始 done — 288 samples from 144 original samples
# 式 done — 284 samples from 142 original samples
# 示 done — 288 samples from 144 original samples
# 士 done — 288 samples from 144 original samples
# 世 done — 288 samples from 144 original samples
# 事 done — 288 samples from 144 original samples
# 是 done — 288 samples from 144 original samples
# 市 done — 288 samples from 144 original samples
# 视 done — 288 samples from 144 original samples
# 收 done — 288 samples from 144 original samples
# 手 done — 288 samples from 144 original samples
# 首 done — 286 samples from 143 original samples
# 受 done — 288 samples from 144 original samples
# 书 done — 288 samples from 144 original samples
# 术 done — 288 samples from 144 original samples
# 数 done — 286 samples from 143 original samples
# 水 done — 288 samples from 144 original samples
# 说 done — 288 samples from 144 original samples
# 斯 done — 288 samples from 144 original samples
# 思 done — 288 samples from 144 original samples
# 司 done — 286 samples from 143 original samples
# 死 done — 288 samples from 144 original samples
# 四 done — 286 samples from 143 original samples
# 似 done — 288 samples from 144 original samples
# 算 done — 288 samples from 144 original samples
# 随 done — 286 samples from 143 original samples
# 所 done — 288 samples from 144 original samples
# 他 done — 288 samples from 144 original samples
# 它 done — 288 samples from 144 original samples
# 她 done — 288 samples from 144 original samples
# 台 done — 288 samples from 144 original samples
# 太 done — 288 samples from 144 original samples
# 谈 done — 288 samples from 144 original samples
# 特 done — 286 samples from 143 original samples
# 提 done — 284 samples from 142 original samples
# 题 done — 288 samples from 144 original samples
# 体 done — 288 samples from 144 original samples
# 天 done — 288 samples from 144 original samples
# 条 done — 288 samples from 144 original samples
# 听 done — 290 samples from 145 original samples
# 通 done — 286 samples from 143 original samples
# 同 done — 288 samples from 144 original samples
# 统 done — 288 samples from 144 original samples
# 头 done — 288 samples from 144 original samples
# 突 done — 288 samples from 144 original samples
# 图 done — 286 samples from 143 original samples
# 团 done — 288 samples from 144 original samples
# 外 done — 288 samples from 144 original samples
# 完 done — 288 samples from 144 original samples
# 万 done — 288 samples from 144 original samples
# 王 done — 288 samples from 144 original samples
# 往 done — 288 samples from 144 original samples
# 望 done — 288 samples from 144 original samples
# 为 done — 288 samples from 144 original samples
# 委 done — 288 samples from 144 original samples
# 未 done — 286 samples from 143 original samples
# 位 done — 288 samples from 144 original samples
# 文 done — 288 samples from 144 original samples
# 问 done — 288 samples from 144 original samples
# 我 done — 288 samples from 144 original samples
# 无 done — 288 samples from 144 original samples
# 五 done — 288 samples from 144 original samples
# 物 done — 288 samples from 144 original samples
# 务 done — 286 samples from 143 original samples
# 西 done — 288 samples from 144 original samples
# 息 done — 286 samples from 143 original samples
# 系 done — 288 samples from 144 original samples
# 下 done — 288 samples from 144 original samples
# 先 done — 288 samples from 144 original samples
# 显 done — 288 samples from 144 original samples
# 现 done — 288 samples from 144 original samples
# 线 done — 288 samples from 144 original samples
# 相 done — 288 samples from 144 original samples
# 想 done — 288 samples from 144 original samples
# 向 done — 288 samples from 144 original samples
# 象 done — 286 samples from 143 original samples
# 消 done — 288 samples from 144 original samples
# 小 done — 288 samples from 144 original samples
# 笑 done — 288 samples from 144 original samples
# 些 done — 288 samples from 144 original samples
# 写 done — 288 samples from 144 original samples
# 新 done — 288 samples from 144 original samples
# 心 done — 286 samples from 143 original samples
# 信 done — 288 samples from 144 original samples
# 形 done — 288 samples from 144 original samples
# 行 done — 288 samples from 144 original samples
# 性 done — 288 samples from 144 original samples
# 需 done — 288 samples from 144 original samples
# 须 done — 286 samples from 143 original samples
# 许 done — 288 samples from 144 original samples
# 选 done — 288 samples from 144 original samples
# 学 done — 288 samples from 144 original samples
# 亚 done — 288 samples from 144 original samples
# 研 done — 288 samples from 144 original samples
# 言 done — 288 samples from 144 original samples
# 眼 done — 288 samples from 144 original samples
# 样 done — 284 samples from 142 original samples
# 要 done — 288 samples from 144 original samples
# 也 done — 288 samples from 144 original samples
# 业 done — 286 samples from 143 original samples
# 一 done — 286 samples from 143 original samples
# 医 done — 288 samples from 144 original samples
# 已 done — 288 samples from 144 original samples
# 以 done — 288 samples from 144 original samples
# 易 done — 288 samples from 144 original samples
# 像 done — 286 samples from 143 original samples

# %%
from feature_extraction import extract_features_batch

x_augmented_train, y_augmented_train = extract_features_batch(augmented_train)
x_augmented_test, y_augmented_test = extract_features_batch(augmented_test)
# Out:
# label 而 complete
# label 儿 complete
# label 尔 complete
# label 二 complete
# label 发 complete
# label 法 complete
# label 反 complete
# label 方 complete
# label 放 complete
# label 非 complete
# label 飞 complete
# label 费 complete
# label 分 complete
# label 风 complete
# label 夫 complete
# label 服 complete
# label 府 complete
# label 复 complete
# label 该 complete
# label 改 complete
# label 干 complete
# label 感 complete
# label 高 complete
# label 告 complete
# label 格 complete
# label 个 complete
# label 各 complete
# label 给 complete
# label 根 complete
# label 更 complete
# label 工 complete
# label 功 complete
# label 公 complete
# label 共 complete
# label 关 complete
# label 官 complete
# label 观 complete
# label 管 complete
# label 光 complete
# label 广 complete
# label 规 complete
# label 国 complete
# label 果 complete
# label 过 complete
# label 海 complete
# label 好 complete
# label 号 complete
# label 和 complete
# label 何 complete
# label 合 complete
# label 很 complete
# label 候 complete
# label 后 complete
# label 乎 complete
# label 花 complete
# label 华 complete
# label 化 complete
# label 话 complete
# label 还 complete
# label 回 complete
# label 会 complete
# label 活 complete
# label 火 complete
# label 或 complete
# label 击 complete
# label 基 complete
# label 机 complete
# label 极 complete
# label 集 complete
# label 及 complete
# label 即 complete
# label 级 complete
# label 几 complete
# label 己 complete
# label 技 complete
# label 济 complete
# label 计 complete
# label 记 complete
# label 际 complete
# label 家 complete
# label 加 complete
# label 价 complete
# label 间 complete
# label 见 complete
# label 件 complete
# label 建 complete
# label 将 complete
# label 交 complete
# label 教 complete
# label 较 complete
# label 叫 complete
# label 接 complete
# label 结 complete
# label 解 complete
# label 界 complete
# label 金 complete
# label 今 complete
# label 仅 complete
# label 进 complete
# label 近 complete
# label 尽 complete
# label 精 complete
# label 经 complete
# label 究 complete
# label 九 complete
# label 就 complete
# label 局 complete
# label 据 complete
# label 具 complete
# label 觉 complete
# label 决 complete
# label 军 complete
# label 开 complete
# label 看 complete
# label 考 complete
# label 科 complete
# label 可 complete
# label 克 complete
# label 空 complete
# label 口 complete
# label 快 complete
# label 况 complete
# label 拉 complete
# label 来 complete
# label 老 complete
# label 类 complete
# label 离 complete
# label 理 complete
# label 李 complete
# label 里 complete
# label 历 complete
# label 利 complete
# label 立 complete
# label 力 complete
# label 联 complete
# label 连 complete
# label 两 complete
# label 量 complete
# label 了 complete
# label 列 complete
# label 林 complete
# label 领 complete
# label 另 complete
# label 令 complete
# label 流 complete
# label 六 complete
# label 路 complete
# label 论 complete
# label 罗 complete
# label 落 complete
# label 马 complete
# label 吗 complete
# label 满 complete
# label 么 complete
# label 没 complete
# label 每 complete
# label 美 complete
# label 门 complete
# label 们 complete
# label 面 complete
# label 民 complete
# label 明 complete
# label 名 complete
# label 命 complete
# label 目 complete
# label 那 complete
# label 南 complete
# label 难 complete
# label 呢 complete
# label 内 complete
# label 能 complete
# label 你 complete
# label 年 complete
# label 念 complete
# label 农 complete
# label 女 complete
# label 片 complete
# label 品 complete
# label 平 complete
# label 期 complete
# label 其 complete
# label 起 complete
# label 企 complete
# label 器 complete
# label 气 complete
# label 前 complete
# label 强 complete
# label 切 complete
# label 且 complete
# label 亲 complete
# label 青 complete
# label 轻 complete
# label 清 complete
# label 情 complete
# label 请 complete
# label 求 complete
# label 区 complete
# label 取 complete
# label 去 complete
# label 权 complete
# label 全 complete
# label 却 complete
# label 确 complete
# label 然 complete
# label 让 complete
# label 人 complete
# label 任 complete
# label 认 complete
# label 日 complete
# label 容 complete
# label 如 complete
# label 入 complete
# label 三 complete
# label 色 complete
# label 山 complete
# label 商 complete
# label 上 complete
# label 少 complete
# label 社 complete
# label 设 complete
# label 身 complete
# label 深 complete
# label 神 complete
# label 声 complete
# label 生 complete
# label 师 complete
# label 失 complete
# label 十 complete
# label 石 complete
# label 时 complete
# label 什 complete
# label 实 complete
# label 识 complete
# label 史 complete
# label 使 complete
# label 始 complete
# label 式 complete
# label 示 complete
# label 士 complete
# label 世 complete
# label 事 complete
# label 是 complete
# label 市 complete
# label 视 complete
# label 收 complete
# label 手 complete
# label 首 complete
# label 受 complete
# label 书 complete
# label 术 complete
# label 数 complete
# label 水 complete
# label 说 complete
# label 斯 complete
# label 思 complete
# label 司 complete
# label 死 complete
# label 四 complete
# label 似 complete
# label 算 complete
# label 随 complete
# label 所 complete
# label 他 complete
# label 它 complete
# label 她 complete
# label 台 complete
# label 太 complete
# label 谈 complete
# label 特 complete
# label 提 complete
# label 题 complete
# label 体 complete
# label 天 complete
# label 条 complete
# label 听 complete
# label 通 complete
# label 同 complete
# label 统 complete
# label 头 complete
# label 突 complete
# label 图 complete
# label 团 complete
# label 外 complete
# label 完 complete
# label 万 complete
# label 王 complete
# label 往 complete
# label 望 complete
# label 为 complete
# label 委 complete
# label 未 complete
# label 位 complete
# label 文 complete
# label 问 complete
# label 我 complete
# label 无 complete
# label 五 complete
# label 物 complete
# label 务 complete
# label 西 complete
# label 息 complete
# label 系 complete
# label 下 complete
# label 先 complete
# label 显 complete
# label 现 complete
# label 线 complete
# label 相 complete
# label 想 complete
# label 像 complete
# label 向 complete
# label 象 complete
# label 消 complete
# label 小 complete
# label 笑 complete
# label 些 complete
# label 写 complete
# label 新 complete
# label 心 complete
# label 信 complete
# label 形 complete
# label 行 complete
# label 性 complete
# label 需 complete
# label 须 complete
# label 许 complete
# label 选 complete
# label 学 complete
# label 亚 complete
# label 研 complete
# label 言 complete
# label 眼 complete
# label 样 complete
# label 要 complete
# label 也 complete
# label 业 complete
# label 一 complete
# label 医 complete
# label 已 complete
# label 以 complete
# label 易 complete
# label 意 complete
# label 义 complete
# label 议 complete
# label 因 complete
# label 引 complete
# label 英 complete
# label 应 complete
# label 影 complete
# label 用 complete
# label 由 complete
# label 有 complete
# label 又 complete
# label 于 complete
# label 与 complete
# label 语 complete
# label 元 complete
# label 原 complete
# label 员 complete
# label 远 complete
# label 院 complete
# label 约 complete
# label 越 complete
# label 月 complete
# label 运 complete
# label 再 complete
# label 在 complete
# label 早 complete
# label 造 complete
# label 则 complete
# label 怎 complete
# label 增 complete
# label 曾 complete
# label 展 complete
# label 战 complete
# label 张 complete
# label 找 complete
# label 照 complete
# label 者 complete
# label 这 complete
# label 真 complete
# label 争 complete
# label 整 complete
# label 正 complete
# label 政 complete
# label 证 complete
# label 支 complete
# label 知 complete
# label 之 complete
# label 直 complete
# label 指 complete
# label 只 complete
# label 至 complete
# label 制 complete
# label 质 complete
# label 治 complete
# label 中 complete
# label 种 complete
# label 重 complete
# label 周 complete
# label 主 complete
# label 住 complete
# label 注 complete
# label 专 complete
# label 转 complete
# label 装 complete
# label 准 complete
# label 着 complete
# label 资 complete
# label 子 complete
# label 自 complete
# label 字 complete
# label 总 complete
# label 走 complete
# label 组 complete
# label 最 complete
# label 做 complete
# label 作 complete
# label 阿 complete
# label 爱 complete
# label 安 complete
# label 吧 complete
# label 八 complete
# label 把 complete
# label 白 complete
# label 百 complete
# label 办 complete
# label 包 complete
# label 保 complete
# label 报 complete
# label 北 complete
# label 备 complete
# label 被 complete
# label 本 complete
# label 比 complete
# label 必 complete
# label 边 complete
# label 便 complete
# label 变 complete
# label 标 complete
# label 表 complete
# label 别 complete
# label 兵 complete
# label 病 complete
# label 并 complete
# label 不 complete
# label 布 complete
# label 步 complete
# label 部 complete
# label 才 complete
# label 查 complete
# label 产 complete
# label 场 complete
# label 常 complete
# label 长 complete
# label 车 complete
# label 称 complete
# label 城 complete
# label 成 complete
# label 程 complete
# label 吃 complete
# label 持 complete
# label 出 complete
# label 除 complete
# label 处 complete
# label 传 complete
# label 此 complete
# label 次 complete
# label 从 complete
# label 存 complete
# label 达 complete
# label 打 complete
# label 大 complete
# label 带 complete
# label 代 complete
# label 单 complete
# label 但 complete
# label 当 complete
# label 党 complete
# label 导 complete
# label 到 complete
# label 道 complete
# label 德 complete
# label 得 complete
# label 的 complete
# label 等 complete
# label 地 complete
# label 第 complete
# label 点 complete
# label 电 complete
# label 调 complete
# label 定 complete
# label 东 complete
# label 动 complete
# label 都 complete
# label 度 complete
# label 断 complete
# label 队 complete
# label 对 complete
# label 多 complete
# label 意 complete
# label 义 complete
# label 议 complete
# label 因 complete
# label 引 complete
# label 英 complete
# label 应 complete
# label 影 complete
# label 用 complete
# label 由 complete
# label 有 complete
# label 又 complete
# label 于 complete
# label 与 complete
# label 语 complete
# label 元 complete
# label 原 complete
# label 员 complete
# label 远 complete
# label 院 complete
# label 约 complete
# label 越 complete
# label 月 complete
# label 运 complete
# label 再 complete
# label 在 complete
# label 早 complete
# label 造 complete
# label 则 complete
# label 怎 complete
# label 增 complete
# label 曾 complete
# label 展 complete
# label 战 complete
# label 张 complete
# label 找 complete
# label 照 complete
# label 者 complete
# label 这 complete
# label 真 complete
# label 争 complete
# label 整 complete
# label 正 complete
# label 政 complete
# label 证 complete
# label 支 complete
# label 知 complete
# label 之 complete
# label 直 complete
# label 指 complete
# label 只 complete
# label 至 complete
# label 制 complete
# label 质 complete
# label 治 complete
# label 中 complete
# label 种 complete
# label 重 complete
# label 周 complete
# label 主 complete
# label 住 complete
# label 注 complete
# label 专 complete
# label 转 complete
# label 装 complete
# label 准 complete
# label 着 complete
# label 资 complete
# label 子 complete
# label 自 complete
# label 字 complete
# label 总 complete
# label 走 complete
# label 组 complete
# label 最 complete
# label 做 complete
# label 作 complete
# label 阿 complete
# label 爱 complete
# label 安 complete
# label 吧 complete
# label 八 complete
# label 把 complete
# label 白 complete
# label 百 complete
# label 办 complete
# label 包 complete
# label 保 complete
# label 报 complete
# label 北 complete
# label 备 complete
# label 被 complete
# label 本 complete
# label 比 complete
# label 必 complete
# label 边 complete
# label 便 complete
# label 变 complete
# label 标 complete
# label 表 complete
# label 别 complete
# label 兵 complete
# label 病 complete
# label 并 complete
# label 不 complete
# label 布 complete
# label 步 complete
# label 部 complete
# label 才 complete
# label 查 complete
# label 产 complete
# label 场 complete
# label 常 complete
# label 长 complete
# label 车 complete
# label 称 complete
# label 城 complete
# label 成 complete
# label 程 complete
# label 吃 complete
# label 持 complete
# label 出 complete
# label 除 complete
# label 处 complete
# label 传 complete
# label 此 complete
# label 次 complete
# label 从 complete
# label 存 complete
# label 达 complete
# label 打 complete
# label 大 complete
# label 带 complete
# label 代 complete
# label 单 complete
# label 但 complete
# label 当 complete
# label 党 complete
# label 导 complete
# label 到 complete
# label 道 complete
# label 德 complete
# label 得 complete
# label 的 complete
# label 等 complete
# label 地 complete
# label 第 complete
# label 点 complete
# label 电 complete
# label 调 complete
# label 定 complete
# label 东 complete
# label 动 complete
# label 都 complete
# label 度 complete
# label 断 complete
# label 队 complete
# label 对 complete
# label 多 complete
# label 而 complete
# label 儿 complete
# label 尔 complete
# label 二 complete
# label 发 complete
# label 法 complete
# label 反 complete
# label 方 complete
# label 放 complete
# label 非 complete
# label 飞 complete
# label 费 complete
# label 分 complete
# label 风 complete
# label 夫 complete
# label 服 complete
# label 府 complete
# label 复 complete
# label 该 complete
# label 改 complete
# label 干 complete
# label 感 complete
# label 高 complete
# label 告 complete
# label 格 complete
# label 个 complete
# label 各 complete
# label 给 complete
# label 根 complete
# label 更 complete
# label 工 complete
# label 功 complete
# label 公 complete
# label 共 complete
# label 关 complete
# label 官 complete
# label 观 complete
# label 管 complete
# label 光 complete
# label 广 complete
# label 规 complete
# label 国 complete
# label 果 complete
# label 过 complete
# label 海 complete
# label 好 complete
# label 号 complete
# label 和 complete
# label 何 complete
# label 合 complete
# label 很 complete
# label 候 complete
# label 后 complete
# label 乎 complete
# label 花 complete
# label 华 complete
# label 化 complete
# label 话 complete
# label 还 complete
# label 回 complete
# label 会 complete
# label 活 complete
# label 火 complete
# label 或 complete
# label 击 complete
# label 基 complete
# label 机 complete
# label 极 complete
# label 集 complete
# label 及 complete
# label 即 complete
# label 级 complete
# label 几 complete
# label 己 complete
# label 技 complete
# label 济 complete
# label 计 complete
# label 记 complete
# label 际 complete
# label 家 complete
# label 加 complete
# label 价 complete
# label 间 complete
# label 见 complete
# label 件 complete
# label 建 complete
# label 将 complete
# label 交 complete
# label 教 complete
# label 较 complete
# label 叫 complete
# label 接 complete
# label 结 complete
# label 解 complete
# label 界 complete
# label 金 complete
# label 今 complete
# label 仅 complete
# label 进 complete
# label 近 complete
# label 尽 complete
# label 精 complete
# label 经 complete
# label 究 complete
# label 九 complete
# label 就 complete
# label 局 complete
# label 据 complete
# label 具 complete
# label 觉 complete
# label 决 complete
# label 军 complete
# label 开 complete
# label 看 complete
# label 考 complete
# label 科 complete
# label 可 complete
# label 克 complete
# label 空 complete
# label 口 complete
# label 快 complete
# label 况 complete
# label 拉 complete
# label 来 complete
# label 老 complete
# label 类 complete
# label 离 complete
# label 理 complete
# label 李 complete
# label 里 complete
# label 历 complete
# label 利 complete
# label 立 complete
# label 力 complete
# label 联 complete
# label 连 complete
# label 两 complete
# label 量 complete
# label 了 complete
# label 列 complete
# label 林 complete
# label 领 complete
# label 另 complete
# label 令 complete
# label 流 complete
# label 六 complete
# label 路 complete
# label 论 complete
# label 罗 complete
# label 落 complete
# label 马 complete
# label 吗 complete
# label 满 complete
# label 么 complete
# label 没 complete
# label 每 complete
# label 美 complete
# label 门 complete
# label 们 complete
# label 面 complete
# label 民 complete
# label 明 complete
# label 名 complete
# label 命 complete
# label 目 complete
# label 那 complete
# label 南 complete
# label 难 complete
# label 呢 complete
# label 内 complete
# label 能 complete
# label 你 complete
# label 年 complete
# label 念 complete
# label 农 complete
# label 女 complete
# label 片 complete
# label 品 complete
# label 平 complete
# label 期 complete
# label 其 complete
# label 起 complete
# label 企 complete
# label 器 complete
# label 气 complete
# label 前 complete
# label 强 complete
# label 切 complete
# label 且 complete
# label 亲 complete
# label 青 complete
# label 轻 complete
# label 清 complete
# label 情 complete
# label 请 complete
# label 求 complete
# label 区 complete
# label 取 complete
# label 去 complete
# label 权 complete
# label 全 complete
# label 却 complete
# label 确 complete
# label 然 complete
# label 让 complete
# label 人 complete
# label 任 complete
# label 认 complete
# label 日 complete
# label 容 complete
# label 如 complete
# label 入 complete
# label 三 complete
# label 色 complete
# label 山 complete
# label 商 complete
# label 上 complete
# label 少 complete
# label 社 complete
# label 设 complete
# label 身 complete
# label 深 complete
# label 神 complete
# label 声 complete
# label 生 complete
# label 师 complete
# label 失 complete
# label 十 complete
# label 石 complete
# label 时 complete
# label 什 complete
# label 实 complete
# label 识 complete
# label 史 complete
# label 使 complete
# label 始 complete
# label 式 complete
# label 示 complete
# label 士 complete
# label 世 complete
# label 事 complete
# label 是 complete
# label 市 complete
# label 视 complete
# label 收 complete
# label 手 complete
# label 首 complete
# label 受 complete
# label 书 complete
# label 术 complete
# label 数 complete
# label 水 complete
# label 说 complete
# label 斯 complete
# label 思 complete
# label 司 complete
# label 死 complete
# label 四 complete
# label 似 complete
# label 算 complete
# label 随 complete
# label 所 complete
# label 他 complete
# label 它 complete
# label 她 complete
# label 台 complete
# label 太 complete
# label 谈 complete
# label 特 complete
# label 提 complete
# label 题 complete
# label 体 complete
# label 天 complete
# label 条 complete
# label 听 complete
# label 通 complete
# label 同 complete
# label 统 complete
# label 头 complete
# label 突 complete
# label 图 complete
# label 团 complete
# label 外 complete
# label 完 complete
# label 万 complete
# label 王 complete
# label 往 complete
# label 望 complete
# label 为 complete
# label 委 complete
# label 未 complete
# label 位 complete
# label 文 complete
# label 问 complete
# label 我 complete
# label 无 complete
# label 五 complete
# label 物 complete
# label 务 complete
# label 西 complete
# label 息 complete
# label 系 complete
# label 下 complete
# label 先 complete
# label 显 complete
# label 现 complete
# label 线 complete
# label 相 complete
# label 想 complete
# label 向 complete
# label 象 complete
# label 消 complete
# label 小 complete
# label 笑 complete
# label 些 complete
# label 写 complete
# label 新 complete
# label 心 complete
# label 信 complete
# label 形 complete
# label 行 complete
# label 性 complete
# label 需 complete
# label 须 complete
# label 许 complete
# label 选 complete
# label 学 complete
# label 亚 complete
# label 研 complete
# label 言 complete
# label 眼 complete
# label 样 complete
# label 要 complete
# label 也 complete
# label 业 complete
# label 一 complete
# label 医 complete
# label 已 complete
# label 以 complete
# label 易 complete
# label 像 complete

# %%
import numpy as np 
np.savez('augmented_features.npz',
    x_augmented_train=x_augmented_train, y_augmented_train=np.array(y_augmented_train),
    x_augmented_test=x_augmented_test,   y_augmented_test=np.array(y_augmented_test)
)

data = np.load('augmented_features.npz', allow_pickle=True)
x_augmented_train = data['x_augmented_train']
y_augmented_train = data['y_augmented_train']
x_augmented_test  = data['x_augmented_test']
y_augmented_test  = data['y_augmented_test']

# %%
from sklearn.model_selection import train_test_split

#create validation set
x_train_sub, x_val, y_train_sub, y_val = train_test_split(
    x_augmented_train, y_augmented_train,
    test_size=0.1,      
    stratify=y_augmented_train    # keeps class proportions balanced
)

# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(y_train_sub)

x_tr = torch.tensor(x_train_sub, dtype=torch.float32)
y_tr = torch.tensor(label_encoder.transform(y_train_sub), dtype=torch.long)
x_v  = torch.tensor(x_val,   dtype=torch.float32)
y_v  = torch.tensor(label_encoder.transform(y_val),   dtype=torch.long)

loader = DataLoader(TensorDataset(x_tr, y_tr), batch_size=256, shuffle=True)

model     = nn.Linear(512, 500)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn   = nn.CrossEntropyLoss()

for epoch in range(20):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        optimizer.zero_grad()
        loss = loss_fn(model(xb), yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    model.eval()
    with torch.no_grad():
        val_preds = model(x_v).argmax(dim=1)
        val_acc   = (val_preds == y_v).float().mean().item()

    print(f"Epoch {epoch+1:2d}  loss={total_loss/len(loader):.4f}  val_acc={val_acc:.3f}")
# Out:
# Epoch  1  loss=1.8945  val_acc=0.760
# Epoch  2  loss=1.0827  val_acc=0.781
# Epoch  3  loss=0.9807  val_acc=0.789
# Epoch  4  loss=0.9313  val_acc=0.792
# Epoch  5  loss=0.8995  val_acc=0.797
# Epoch  6  loss=0.8774  val_acc=0.802
# Epoch  7  loss=0.8609  val_acc=0.802
# Epoch  8  loss=0.8477  val_acc=0.806
# Epoch  9  loss=0.8363  val_acc=0.809
# Epoch 10  loss=0.8282  val_acc=0.810
# Epoch 11  loss=0.8189  val_acc=0.809
# Epoch 12  loss=0.8130  val_acc=0.810
# Epoch 13  loss=0.8064  val_acc=0.810
# Epoch 14  loss=0.8009  val_acc=0.811
# Epoch 15  loss=0.7958  val_acc=0.812
# Epoch 16  loss=0.7903  val_acc=0.811
# Epoch 17  loss=0.7869  val_acc=0.815
# Epoch 18  loss=0.7834  val_acc=0.815
# Epoch 19  loss=0.7789  val_acc=0.813
# Epoch 20  loss=0.7756  val_acc=0.814

# %%
x_te = torch.tensor(x_augmented_test, dtype=torch.float32)
y_te = torch.tensor(label_encoder.transform(y_augmented_test), dtype=torch.long)

model.eval()
with torch.no_grad():
    test_preds = model(x_te).argmax(dim=1)
    test_acc   = (test_preds == y_te).float().mean().item()

print(f"Test acc: {test_acc:.3f}")
# Out:
# Test acc: 0.790

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 21))
loss    = [1.8945,1.0827,0.9807,0.9313,0.8995,0.8774,0.8609,0.8477,0.8363,0.8282,
           0.8189,0.8130,0.8064,0.8009,0.7958,0.7903,0.7869,0.7834,0.7789,0.7756]
val_acc = [0.760,0.781,0.789,0.792,0.797,0.802,0.802,0.806,0.809,0.810,
           0.809,0.810,0.810,0.811,0.812,0.811,0.815,0.815,0.813,0.814]

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(epochs, loss, color='gray', linestyle='--', marker='o', ms=4, label='train loss')
ax1.set_xlabel('epoch')
ax1.set_ylabel('train loss', color='gray')
ax1.tick_params(axis='y', labelcolor='gray')

ax2 = ax1.twinx()
ax2.plot(epochs, val_acc, color='#1D9E75', marker='o', ms=4, label='val accuracy')
ax2.set_ylabel('val accuracy', color='#1D9E75')
ax2.tick_params(axis='y', labelcolor='#1D9E75')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0%}'))

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Training curves — logistic regression CASIA dataset augmented')
plt.tight_layout()
plt.show()

# %%
print(len(train))
print(len(test))
print(len(augmented_train))
print(len(augmented_test))
# Out:
# 500
# 500
# 500
# 500
# [[[(5840, 4515), (5844, 4515), (5848, 4518), (5846, 4527), (5828, 4575), (5818, 4590), (5828, 4570), (5840, 4561), (5848, 4568), (5850, 4596), (5848, 4613), (5846, 4630), (5844, 4640), (5844, 4642), (5844, 4641), (5850, 4601), (5856, 4577), (5864, 4557)], [(5891, 4512), (5900, 4502), (5910, 4491), (5918, 4492), (5903, 4538), (5936, 4521), (5955, 4518), (5946, 4530), (5925, 4540), (5931, 4641), (5914, 4625), (5891, 4591), (5884, 4597), (5880, 4620), (5894, 4615), (5923, 4597), (5941, 4592), (5960, 4591), (5974, 4595), (5993, 4610), (5991, 4610), (5985, 4605), (5961, 4586)]], [[(5854, 1171), (5854, 1175), (5829, 1233), (5801, 1285), (5791, 1296), (5786, 1299), (5784, 1294), (5789, 1273), (5799, 1245)], [(5836, 1234), (5844, 1241), (5850, 1259), (5840, 1341), (5836, 1359), (5835, 1364), (5836, 1363), (5846, 1310), (5851, 1254), (5859, 1190)], [(5898, 1164), (5904, 1168), (5904, 1174), (5888, 1213), (5893, 1218), (5959, 1210), (5970, 1213), (5973, 1229), (5950, 1256), (5915, 1279), (5896, 1279), (5885, 1268), (5879, 1244)], [(5906, 1233), (5914, 1238), (5921, 1249), (5928, 1285), (5925, 1338), (5916, 1365), (5914, 1366), (5903, 1360), (5889, 1346), (5871, 1319), (5855, 1281), (5849, 1253)], [(5883, 1271), (5890, 1275), (5895, 1290), (5888, 1316), (5881, 1329), (5879, 1335), (5881, 1324), (5889, 1295)], [(5938, 1295), (5949, 1299), (5971, 1314), (5984, 1311), (5988, 1291), (5989, 1258)]], [[(5871, 7841), (5868, 7843), (5856, 7851), (5815, 7900), (5813, 7901), (5831, 7889), (5839, 7890), (5844, 7898), (5848, 7946), (5845, 7968), (5843, 7966)], [(5913, 7816), (5915, 7818), (5914, 7825), (5908, 7839), (5881, 7869), (5924, 7846), (5944, 7843), (5966, 7849), (5959, 7868), (5936, 7885), (5925, 7891), (5910, 7893), (5910, 7880), (5916, 7876), (5919, 7881), (5920, 7894), (5915, 8025), (5914, 8029), (5908, 8023), (5905, 8010), (5901, 7989)], [(5900, 7908), (5900, 7910), (5876, 7985), (5860, 8006), (5855, 8005), (5853, 7996)], [(5938, 7934), (5969, 7944), (6000, 7959), (5990, 7955)]], [[(5858, 7785), (5859, 7790), (5831, 7822), (5814, 7834), (5778, 7852)], [(5814, 7824), (5820, 7824), (5826, 7829), (5833, 7852), (5826, 7910), (5821, 7920), (5819, 7925), (5816, 7920)], [(5895, 7775), (5896, 7774), (5864, 7844), (5844, 7865)], [(5849, 7825), (5860, 7820), (5896, 7809), (5935, 7800), (5950, 7804), (5929, 7835), (5906, 7855), (5881, 7867), (5878, 7862), (5878, 7854)], [(5884, 7840), (5889, 7835), (5891, 7830), (5894, 7827), (5894, 7829), (5895, 7902), (5893, 7915), (5884, 7925), (5876, 7920), (5855, 7875), (5849, 7847), (5858, 7879), (5856, 7900), (5854, 7915)], [(5960, 7872), (5963, 7875), (5971, 7885), (5968, 7912), (5964, 7925), (5950, 7934)]], [[(5866, 7772), (5869, 7770), (5866, 7772), (5815, 7850), (5843, 7817), (5856, 7812), (5860, 7825), (5853, 7894), (5893, 7770), (5906, 7745), (5911, 7744), (5910, 7752), (5908, 7760), (5898, 7777), (5940, 7765), (5968, 7767), (5963, 7782), (5949, 7795), (5930, 7800), (5921, 7795), (5930, 7870), (5926, 7907), (5914, 7929), (5909, 7920), (5898, 7890), (5895, 7825), (5900, 7819), (5889, 7844), (5868, 7870), (5864, 7872), (5865, 7869), (5870, 7855)], [(5963, 7822), (5970, 7832), (5974, 7845), (5994, 7894), (5991, 7890), (5981, 7874)]], [[(4533, 2268), (4535, 2261), (4534, 2258), (4473, 2308), (4453, 2310), (4470, 2316), (4483, 2328), (4493, 2363), (4480, 2416), (4469, 2435), (4468, 2418)], [(4554, 2276), (4559, 2266), (4560, 2263), (4550, 2276), (4528, 2306), (4601, 2293), (4614, 2300), (4600, 2331), (4589, 2345), (4579, 2348), (4568, 2341)], [(4564, 2293), (4564, 2296), (4561, 2360), (4550, 2428), (4541, 2410), (4531, 2401), (4519, 2395), (4505, 2386)], [(4504, 2353), (4504, 2355), (4499, 2388), (4511, 2395), (4539, 2390), (4581, 2370), (4623, 2358), (4643, 2365), (4649, 2373), (4640, 2393), (4633, 2396), (4629, 2395), (4629, 2386)]], [[(4539, 2303), (4539, 2303), (4538, 2305), (4494, 2354), (4474, 2373), (4470, 2375), (4475, 2368), (4486, 2353)], [(4525, 2321), (4524, 2324), (4523, 2329), (4513, 2415), ( ...

# %%
sample = chars0_train['你'][1]
print(f"Number of strokes: {len(sample)}")
for i, stroke in enumerate(sample):
    print(f"  Stroke {i}: {len(stroke)} points, first={stroke[0]}, last={stroke[-1]}")
# Out:
# Number of strokes: 6
#   Stroke 0: 9 points, first=(5854, 1171), last=(5799, 1245)
#   Stroke 1: 10 points, first=(5836, 1234), last=(5859, 1190)
#   Stroke 2: 13 points, first=(5898, 1164), last=(5879, 1244)
#   Stroke 3: 12 points, first=(5906, 1233), last=(5849, 1253)
#   Stroke 4: 8 points, first=(5883, 1271), last=(5889, 1295)
#   Stroke 5: 6 points, first=(5938, 1295), last=(5989, 1258)

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
import numpy as np
from sklearn.preprocessing import LabelEncoder

device = (
    'cuda' if torch.cuda.is_available()
    else 'mps' if torch.backends.mps.is_available()
    else 'cpu'
)
print(f"using {device}")

#add stroke index to each point, at add mask
def strokes_to_sequence(strokes, max_len=128):
    points = []
    for stroke_id, stroke in enumerate(strokes):
        stroke = np.array(stroke)
        for pt in stroke:
            points.append([pt[0], pt[1], stroke_id])
        if len(points) >= max_len:
            break

    points = points[:max_len]
    seq_len = len(points)

    padded = np.zeros((max_len, 3), dtype=np.float32)
    padded[:seq_len] = points

    mask = torch.zeros(max_len, dtype=torch.bool)
    mask[:seq_len] = True

    return torch.tensor(padded, dtype=torch.float32), mask


class StrokeDataset(Dataset):
    def __init__(self, chars_dict, label_encoder, max_len=128):
        self.samples = []
        self.max_len = max_len
        for char, samples in chars_dict.items():
            label = label_encoder.transform([char])[0]
            for strokes in samples:
                self.samples.append((strokes, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        strokes, label = self.samples[idx]
        seq, mask = strokes_to_sequence(strokes, self.max_len)
        return seq, mask, label


class StrokeTransformer(nn.Module):
    def __init__(self, n_classes=500, d_model=64, nhead=4,
                 num_layers=2, max_len=128, dropout=0.1):
        super().__init__()

        self.input_proj  = nn.Linear(3, d_model)
        self.pos_embedding = nn.Embedding(max_len, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=d_model * 4,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.classifier  = nn.Linear(d_model, n_classes)

    def forward(self, x, mask):
        B, L, _ = x.shape
        x = self.input_proj(x)
        pos = torch.arange(L, device=x.device).unsqueeze(0)
        x = x + self.pos_embedding(pos)
        pad_mask = ~mask
        x = self.transformer(x, src_key_padding_mask=pad_mask)
        mask_f = mask.unsqueeze(-1).float()
        x = (x * mask_f).sum(dim=1) / mask_f.sum(dim=1)
        return self.classifier(x)


label_encoder = LabelEncoder()
label_encoder.fit(list(train.keys()))

train_dataset = StrokeDataset(train, label_encoder, max_len=128)
val_dataset   = StrokeDataset(val,   label_encoder, max_len=128)

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True,  num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=512, shuffle=False, num_workers=4, pin_memory=True)

model     = StrokeTransformer(n_classes=500).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
loss_fn   = nn.CrossEntropyLoss()
scaler    = GradScaler()

print(f"train samples : {len(train_dataset):,}")
print(f"val samples   : {len(val_dataset):,}")
print(f"parameters    : {sum(p.numel() for p in model.parameters()):,}")

best_val_acc = 0.0

for epoch in range(30):
    model.train()
    total_loss = 0
    for x, mask, y in train_loader:
        x, mask, y = x.to(device), mask.to(device), y.to(device)
        optimizer.zero_grad()
        with autocast():
            loss = loss_fn(model(x, mask), y)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    model.eval()
    correct = 0
    with torch.no_grad():
        for x, mask, y in val_loader:
            x, mask, y = x.to(device), mask.to(device), y.to(device)
            correct += (model(x, mask).argmax(dim=1) == y).sum().item()

    val_acc = correct / len(val_dataset)
    print(f"Epoch {epoch+1:2d}  loss={total_loss/len(train_loader):.4f}  val_acc={val_acc:.3f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), 'best_model.pt')
        print(f"  saved best model ({val_acc:.3f})")

    scheduler.step()

print(f"\nbest val acc: {best_val_acc:.3f}")
